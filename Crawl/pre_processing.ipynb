# %%
import logging
import re
import os
from typing import Any, Dict, List, Tuple
from dotenv import load_dotenv
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure, ConfigurationError, InvalidName
from sklearn.model_selection import train_test_split


logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def fetch_data_from_mongo(mongo_uri: str, collection: str, db_name: str):
    logging.info(f"Input params: mongo_uri={mongo_uri}, db={db_name}, collection={collection}")
    try:
        client = MongoClient(mongo_uri)
        logging.info("MongoClient created successfully.")

        db = client[db_name]
        logging.info(f"Database '{db_name}' accessed successfully.")
        
        col = db[collection]
        logging.info(f"Collection '{collection}' ready to use.")

        return col

    except ConfigurationError as e:
        logging.error(f"MongoDB Configuration Error: {e}")
    except ConnectionFailure as e:
        logging.error(f"Cannot connect to MongoDB server: {e}")
    except InvalidName as e:
        logging.error(f"Invalid database or collection name: {e}")
    except Exception as e:
        logging.error(f"Unexpected error occurred: {e}")

    logging.warning("Returning None due to previous errors.")
    return None

def convert_to_bio(tasks):
    bio_samples = []
    for task in tasks:
        text = task.get("data", {}).get("text")
        if not text:
            continue
        spans = _get_spans(task)
        tokens_with_tags = _find_bio_in_text(text, spans)
    
        if tokens_with_tags:
            bio_samples.append(tokens_with_tags)
            
    return bio_samples        
    
        

def _get_spans(task):
    annotation = task.get("annotations")[0].get('result')
    spans = []
    for anno in annotation:
        start = anno.get('value').get("start")
        end = anno.get('value').get("end")
        label = anno.get('value').get("labels") 
        if 'O' not in label:
            spans.append((start,end,label))
            
    return spans

def _find_bio_in_text(text, spans):
    tokens_w_tags = []
    for match in re.finditer(r"[^,;\s.]+", text):
        token = match.group()
        start_tok = match.start()
        end_tok = match.end()
        
        tag = 'O'
        
        for start, end, label in spans:
            if start_tok >= start and end_tok <= end+1:
                if start_tok== start:
                    tag = f'B-{label[0]}'
                else: 
                    tag = f'I-{label[0]}'
                continue
        
        tokens_w_tags.append((token, tag))
        
    return tokens_w_tags
        
    

def split_train_valid(
    bio_samples: List[Dict[str, Any]], 
    valid_ratio: float = 0.1,
    seed: int = 42
    ) -> Tuple[List[Dict[str, Any]], List[Dict[str, Any]]]:
    if not bio_samples:
        return [], []
    
    train_samples, valid_samples = train_test_split(
        bio_samples,
        test_size=valid_ratio,
        random_state=seed,
        shuffle=True
    )
    
    return train_samples, valid_samples

# %%
col = fetch_data_from_mongo(
    mongo_uri="mongodb+srv://admin:admin123@label-studio.w0lrldm.mongodb.net/?appName=label-studio",
    db_name="label-studio",
    collection="ner-labeled-output",
)

cursor= col.find({})
tasks = cursor.to_list()

bio_samples = convert_to_bio(tasks)
train_set, valid_set = split_train_valid(bio_samples, valid_ratio=0.1)
# Out:
# 2025-12-10 21:32:13,926 - INFO - Input params: mongo_uri=mongodb+srv://admin:admin123@label-studio.w0lrldm.mongodb.net/?appName=label-studio, db=label-studio, collection=ner-labeled-output
# 2025-12-10 21:32:13,993 - INFO - MongoClient created successfully.
# 2025-12-10 21:32:13,994 - INFO - Database 'label-studio' accessed successfully.
# 2025-12-10 21:32:13,994 - INFO - Collection 'ner-labeled-output' ready to use.

# %%
import json
from pathlib import Path
from typing import List, Tuple, Dict, Any


def convert_corpus_to_jsonl(
    corpus: List[List[Tuple[str, str]]],
    jsonl_path: str,
    labels_path: str | None = None,
    drop_empty: bool = True,
) -> None:
    """
    Convert a corpus dạng:
        corpus = [
            [("Token1", "LABEL1"), ("Token2", "LABEL2"), ...],
            [("TokenA", "LABELX"), ("TokenB", "LABELY"), ...],
            ...
        ]

    → ghi ra JSONL:
        {"tokens": [...], "labels": [...]}

    Option: lưu luôn labels vào file labels_path (vd: labels.json)
    """

    jsonl_file = Path(jsonl_path)
    jsonl_file.parent.mkdir(parents=True, exist_ok=True)

    all_labels: set[str] = set()
    num_samples = 0

    with jsonl_file.open("w", encoding="utf-8") as f_out:
        for sent_idx, sentence in enumerate(corpus):

            if not sentence:
                if drop_empty:
                    continue
                else:
                    # nếu không muốn drop, vẫn ghi sample rỗng
                    entry = {"tokens": [], "labels": []}
                    f_out.write(json.dumps(entry, ensure_ascii=False) + "\n")
                    num_samples += 1
                    continue

            tokens = []
            labels = []

            for token, label in sentence:
                tokens.append(token)
                labels.append(label)
                all_labels.add(label)

            # sanity check: độ dài phải bằng nhau
            if len(tokens) != len(labels):
                raise ValueError(
                    f"Sentence {sent_idx} có số token != số label "
                    f"({len(tokens)} vs {len(labels)})"
                )

            entry: Dict[str, Any] = {
                "tokens": tokens,
                "labels": labels,
            }

            f_out.write(json.dumps(entry, ensure_ascii=False) + "\n")
            num_samples += 1

    print(f"✅ Đã ghi {num_samples} câu vào: {jsonl_file}")

    # nếu muốn lưu mapping label
    if labels_path is not None:
        labels_file = Path(labels_path)
        labels_file.parent.mkdir(parents=True, exist_ok=True)

        sorted_labels = sorted(all_labels)
        label2id = {label: idx for idx, label in enumerate(sorted_labels)}

        with labels_file.open("w", encoding="utf-8") as f_lb:
            json.dump(
                {
                    "labels": sorted_labels,
                    "label2id": label2id,
                },
                f_lb,
                ensure_ascii=False,
                indent=2,
            )

        print(f"✅ Đã lưu labels vào: {labels_file}")
        print("   Nhãn:", sorted_labels)


# ==========================
# VÍ DỤ SỬ DỤNG
# ==========================
if __name__ == "__main__":
    # Ví dụ: bạn có 1 corpus như này (thay bằng dữ liệu thật của bạn)
    corpus = [
        [
            ("Sau", "O"),
            ("1", "O"),
            ("thời", "O"),
            ("gian", "O"),
            ("sử", "O"),
            ("dụng", "O"),
            ("mờ", "B-BENEFITS"),
            ("thâm", "I-BENEFITS"),
        ],
        [
            ("Vitamin", "B-NAME"),
            ("C", "I-NAME"),
            ("có", "O"),
            ("tác", "B-BENEFITS"),
            ("dụng", "I-BENEFITS"),
        ],
        # ... thêm nhiều câu nữa
    ]

    # Ghi ra file JSONL + labels
    convert_corpus_to_jsonl(
        corpus=corpus,
        jsonl_path="output/ner_dataset.jsonl",
        labels_path="output/labels.json",
        drop_empty=True,
    )

# %%
for item in train_set:
    print(item)
# Out:
# [('Sau', 'O'), ('1', 'O'), ('thời', 'O'), ('gian', 'O'), ('sử', 'O'), ('dụng', 'O'), ('(từ', 'O'), ('8', 'O'), ('–', 'O'), ('12', 'O'), ('tuần)', 'O'), ('làn', 'O'), ('da', 'O'), ('sẽ', 'O'), ('nhận', 'O'), ('được', 'O'), ('các', 'O'), ('thay', 'O'), ('đổi', 'O'), ('tích', 'O'), ('cực', 'O'), ('như', 'O'), ('mờ', 'B-BENEFITS'), ('thâm', 'I-BENEFITS'), ('tàn', 'O'), ('nhang', 'O'), ('tăng', 'B-BENEFITS'), ('độ', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('mờ', 'B-BENEFITS'), ('nếp', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('cũng', 'O'), ('như', 'O'), ('cải', 'B-BENEFITS'), ('thiện', 'I-BENEFITS'), ('kết', 'I-BENEFITS'), ('cấu', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('tổng', 'I-BENEFITS'), ('thể', 'I-BENEFITS'), ('làn', 'O'), ('da', 'O'), ('ngày', 'O'), ('càng', 'O'), ('trở', 'O'), ('nên', 'O'), ('rạng', 'O'), ('rỡ', 'O'), ('đều', 'O'), ('màu', 'O'), ('và', 'O'), ('trẻ', 'O'), ('trung', 'O'), ('hơn', 'O')]
# [('Trong', 'O'), ('mỹ', 'O'), ('phẩm', 'O'), ('Trehalose', 'B-NAME'), ('thường', 'O'), ('được', 'O'), ('chiết', 'O'), ('xuất', 'O'), ('từ', 'O'), ('thực', 'O'), ('vật', 'O'), ('như', 'O'), ('ngô', 'B-ORIGIN'), ('hoặc', 'O'), ('tổng', 'B-ORIGIN'), ('hợp', 'I-ORIGIN'), ('trong', 'I-ORIGIN'), ('phòng', 'I-ORIGIN'), ('thí', 'I-ORIGIN'), ('nghiệm', 'I-ORIGIN')]
# [('BHA', 'B-NAME'), ('cũng', 'O'), ('có', 'O'), ('đặc', 'O'), ('tính', 'O'), ('làm', 'B-BENEFITS'), ('dịu', 'I-BENEFITS'), ('mẩn', 'I-BENEFITS'), ('đỏ', 'I-BENEFITS'), ('vì', 'O'), ('vậy', 'O'), ('bạn', 'O'), ('nên', 'O'), ('chọn', 'O'), ('loại', 'O'), ('phù', 'O'), ('hợp', 'O'), ('với', 'O'), ('những', 'O'), ('mối', 'O'), ('quan', 'O'), ('tâm', 'O'), ('của', 'O'), ('bạn', 'O')]
# [('Adenosine', 'B-NAME'), ('là', 'O'), ('một', 'O'), ('thành', 'O'), ('phần', 'O'), ('phổ', 'O'), ('biến', 'O'), ('trong', 'O'), ('mỹ', 'O'), ('phẩm', 'O'), ('đặc', 'O'), ('biệt', 'O'), ('là', 'O'), ('các', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('chống', 'B-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS')]
# [('Công', 'O'), ('dụng', 'O'), ('của', 'O'), ('Peptide', 'B-NAME'), ('là', 'O'), ('gì', 'O'), ('trong', 'O'), ('việc', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('Theo', 'O'), ('các', 'O'), ('nhà', 'O'), ('nghiên', 'O'), ('cứu', 'O'), ('khoa', 'O'), ('học', 'O'), ('Peptide', 'O'), ('chính', 'O'), ('là', 'O'), ('các', 'O'), ('đoạn', 'O'), ('protein', 'O'), ('được', 'B-ORIGIN'), ('tạo', 'I-ORIGIN'), ('thành', 'I-ORIGIN'), ('từ', 'I-ORIGIN'), ('các', 'I-ORIGIN'), ('amino', 'I-ORIGIN'), ('acid', 'I-ORIGIN'), ('(thường', 'O'), ('gọi', 'O'), ('là', 'O'), ('acid', 'O'), ('amin)', 'O')]
# [('Khi', 'O'), ('nhận', 'O'), ('thấy', 'O'), ('làn', 'O'), ('da', 'O'), ('đang', 'O'), ('có', 'B-SKIN_CONCERNS'), ('dấu', 'I-SKIN_CONCERNS'), ('hiệu', 'I-SKIN_CONCERNS'), ('suy', 'I-SKIN_CONCERNS'), ('giảm', 'I-SKIN_CONCERNS'), ('Collagen', 'I-SKIN_CONCERNS'), ('Retinol', 'O'), ('sẽ', 'O'), ('ra', 'O'), ('tín', 'O'), ('hiệu', 'O'), ('để', 'O'), ('kích', 'O'), ('thích', 'O'), ('quá', 'O'), ('trình', 'O'), ('này', 'O'), ('của', 'O'), ('làn', 'O'), ('da', 'O'), ('từ', 'O'), ('đó', 'O'), ('tăng', 'B-BENEFITS'), ('cường', 'I-BENEFITS'), ('kết', 'I-BENEFITS'), ('cấu', 'I-BENEFITS'), ('cho', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('săn', 'O'), ('chắc', 'O'), ('làm', 'B-BENEFITS'), ('mờ', 'I-BENEFITS'), ('các', 'I-BENEFITS'), ('nếp', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('trên', 'O'), ('da', 'O')]
# [('Dược', 'O'), ('phẩm:', 'O'), ('Kojic', 'B-NAME'), ('Acid', 'I-NAME'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('hoạt', 'O'), ('động', 'O'), ('như', 'O'), ('một', 'O'), ('chất', 'O'), ('bảo', 'B-BENEFITS'), ('vệ', 'I-BENEFITS'), ('tia', 'I-BENEFITS'), ('cực', 'I-BENEFITS'), ('tím', 'I-BENEFITS'), ('ức', 'B-BENEFITS'), ('chế', 'I-BENEFITS'), ('sự', 'I-BENEFITS'), ('tăng', 'I-BENEFITS'), ('sắc', 'I-BENEFITS'), ('tố', 'I-BENEFITS'), ('ở', 'O'), ('người', 'O'), ('và', 'O'), ('hạn', 'B-BENEFITS'), ('chế', 'I-BENEFITS'), ('sự', 'I-BENEFITS'), ('hình', 'I-BENEFITS'), ('thành', 'I-BENEFITS'), ('melanin', 'I-BENEFITS')]
# [('Thành', 'O'), ('phần:', 'O'), ('Bộ', 'O'), ('3', 'O'), ('chiết', 'O'), ('xuất', 'O'), ('hoa', 'O'), ('cúc', 'O'), ('(bisabolol', 'O'), ('allantoin', 'O'), ('ormenis', 'O'), ('multicaulis', 'O'), ('flower', 'O'), ('oil):', 'O'), ('Tăng', 'O'), ('cường', 'O'), ('tác', 'O'), ('động', 'O'), ('dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('chống', 'B-BENEFITS'), ('oxy', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('giảm', 'B-BENEFITS'), ('viêm', 'I-BENEFITS'), ('và', 'O'), ('chữa', 'B-BENEFITS'), ('lành', 'I-BENEFITS'), ('các', 'I-BENEFITS'), ('vết', 'I-BENEFITS'), ('thương', 'I-BENEFITS'), ('trên', 'O'), ('da', 'O')]
# [('Ferulic', 'B-NAME'), ('Acid:', 'I-NAME'), ('Công', 'O'), ('dụng:', 'O'), ('Sản', 'O'), ('phẩm', 'O'), ('chứa', 'O'), ('Tetrahexyldecyl', 'O'), ('Ascorbate', 'O'), ('–', 'O'), ('một', 'O'), ('dẫn', 'O'), ('xuất', 'O'), ('vitamin', 'B-ORIGIN'), ('C', 'I-ORIGIN'), ('ổn', 'O'), ('định', 'O'), ('thẩm', 'O'), ('thấu', 'O'), ('tốt', 'O')]
# [('Resveratrol:', 'O'), ('Resveratrol', 'B-NAME'), ('là', 'O'), ('hoạt', 'O'), ('chất', 'O'), ('có', 'O'), ('nguồn', 'O'), ('gốc', 'O'), ('thực', 'B-ORIGIN'), ('vật', 'I-ORIGIN'), ('hoạt', 'O'), ('động', 'O'), ('như', 'O'), ('một', 'O'), ('chất', 'O'), ('chống', 'B-BENEFITS'), ('oxy', 'I-BENEFITS'), ('hóa', 'I-BENEFITS')]
# [('Tuỳ', 'O'), ('vào', 'O'), ('loại', 'O'), ('phân', 'O'), ('tử', 'O'), ('được', 'O'), ('kết', 'O'), ('nối', 'O'), ('Beta', 'B-NAME'), ('glucan', 'I-NAME'), ('sẽ', 'O'), ('mang', 'O'), ('lại', 'O'), ('những', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('khác', 'O'), ('nhau', 'O'), ('như', 'O'), ('hút', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('làm', 'B-BENEFITS'), ('mờ', 'I-BENEFITS'), ('nếp', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('sản', 'B-BENEFITS'), ('sinh', 'I-BENEFITS'), ('collagen', 'I-BENEFITS'), ('và', 'O'), ('kích', 'B-BENEFITS'), ('thích', 'I-BENEFITS'), ('hệ', 'I-BENEFITS'), ('miễn', 'I-BENEFITS'), ('dịch', 'I-BENEFITS')]
# [('Sử', 'O'), ('dụng', 'O'), ('Niacinamide', 'B-NAME'), ('giúp', 'O'), ('lỗ', 'B-SKIN_CONCERNS'), ('chân', 'I-SKIN_CONCERNS'), ('lông', 'I-SKIN_CONCERNS'), ('thông', 'I-SKIN_CONCERNS'), ('thoáng', 'I-SKIN_CONCERNS'), ('và', 'O'), ('ngăn', 'B-SKIN_CONCERNS'), ('ngừa', 'I-SKIN_CONCERNS'), ('tình', 'I-SKIN_CONCERNS'), ('trạng', 'I-SKIN_CONCERNS'), ('mụn', 'I-SKIN_CONCERNS'), ('Hàng', 'O'), ('rào', 'O'), ('bảo', 'O'), ('vệ', 'O'), ('da', 'O'), ('vô', 'O'), ('cùng', 'O'), ('quan', 'O'), ('trọng', 'O'), ('khi', 'O'), ('giúp', 'O'), ('da', 'O'), ('hạn', 'O'), ('chế', 'O'), ('khỏi', 'O'), ('những', 'O'), ('xâm', 'O'), ('nhập', 'O'), ('có', 'O'), ('hại', 'O'), ('từ', 'O'), ('bên', 'O'), ('ngoài', 'O'), ('khiến', 'O'), ('da', 'B-SKIN_CONCERNS'), ('mất', 'I-SKIN_CONCERNS'), ('cân', 'I-SKIN_CONCERNS'), ('bằng', 'I-SKIN_CONCERNS'), ('ẩm', 'I-SKIN_CONCERNS')]
# [('Đặc', 'O'), ('biệt', 'O'), ('LA', 'B-NAME'), ('điều', 'O'), ('chỉnh', 'O'), ('phản', 'O'), ('ứng', 'O'), ('viêm', 'O'), ('thông', 'O'), ('qua', 'O'), ('việc', 'O'), ('kích', 'O'), ('hoạt', 'O'), ('các', 'O'), ('yếu', 'O'), ('tố', 'O'), ('như', 'O'), ('MMP-9', 'O'), ('IL-8', 'O'), ('thông', 'O'), ('qua', 'O'), ('thụ', 'O'), ('thể', 'O'), ('FFAR1', 'O'), ('giúp', 'O'), ('tăng', 'B-BENEFITS'), ('tốc', 'I-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('phục', 'I-BENEFITS'), ('hồi', 'I-BENEFITS')]
# [('Hexylresorcinol', 'B-NAME'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('thúc', 'B-BENEFITS'), ('đẩy', 'I-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('tự', 'I-BENEFITS'), ('sản', 'I-BENEFITS'), ('sinh', 'I-BENEFITS'), ('Collagen', 'I-BENEFITS'), ('của', 'O'), ('da', 'O'), ('từ', 'O'), ('đó', 'O'), ('tăng', 'B-BENEFITS'), ('cường', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('đẩy', 'B-BENEFITS'), ('lùi', 'I-BENEFITS'), ('các', 'I-BENEFITS'), ('dấu', 'I-BENEFITS'), ('hiệu', 'I-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('như', 'O'), ('da', 'B-SKIN_CONCERNS'), ('chùng', 'I-SKIN_CONCERNS'), ('nhão', 'I-SKIN_CONCERNS'), ('nếp', 'B-SKIN_CONCERNS'), ('nhăn', 'I-SKIN_CONCERNS'), ('và', 'O'), ('rãnh', 'B-SKIN_CONCERNS'), ('nhăn', 'I-SKIN_CONCERNS'), ('sâu', 'I-SKIN_CONCERNS')]
# [('Trehalose', 'B-NAME'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('hút', 'B-BENEFITS'), ('và', 'I-BENEFITS'), ('giữ', 'I-BENEFITS'), ('nước', 'I-BENEFITS'), ('giúp', 'O'), ('duy', 'B-BENEFITS'), ('trì', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('cho', 'I-BENEFITS'), ('da', 'I-BENEFITS')]
# [('Chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('bằng', 'O'), ('Retinal', 'B-NAME'), ('đòi', 'O'), ('hỏi', 'O'), ('sự', 'O'), ('cẩn', 'O'), ('thận', 'O'), ('và', 'O'), ('tỉ', 'O'), ('mỉ', 'O'), ('rất', 'O'), ('cao', 'O')]
# [('Betaine', 'B-NAME'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('cải', 'B-BENEFITS'), ('thiện', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('mịn', 'I-BENEFITS'), ('màng', 'I-BENEFITS'), ('và', 'O'), ('làm', 'I-BENEFITS'), ('đầy', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('giúp', 'B-BENEFITS'), ('giảm', 'I-BENEFITS'), ('thiểu', 'I-BENEFITS'), ('rõ', 'I-BENEFITS'), ('rệt', 'I-BENEFITS'), ('sự', 'I-BENEFITS'), ('xuất', 'I-BENEFITS'), ('hiện', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('các', 'I-BENEFITS'), ('nếp', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('và', 'I-BENEFITS'), ('vết', 'I-BENEFITS'), ('chân', 'I-BENEFITS'), ('chim', 'I-BENEFITS')]
# [('Khi', 'O'), ('da', 'O'), ('được', 'O'), ('bổ', 'O'), ('sung', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('da', 'O'), ('sẽ', 'O'), ('trở', 'O'), ('nên', 'O'), ('đủ', 'O'), ('ẩm', 'O'), ('căng', 'O'), ('mọng', 'O'), ('từ', 'O'), ('đó', 'O'), ('ngăn', 'B-BENEFITS'), ('ngừa', 'I-BENEFITS'), ('được', 'I-BENEFITS'), ('như', 'I-BENEFITS'), ('vết', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('nông', 'I-BENEFITS'), ('hoặc', 'O'), ('nếp', 'B-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('sâu', 'I-BENEFITS'), ('hiệu', 'O'), ('quả', 'O')]
# [('Các', 'O'), ('hợp', 'O'), ('chất', 'O'), ('như', 'O'), ('axit', 'O'), ('amin', 'O'), ('và', 'O'), ('axit', 'O'), ('béo', 'O'), ('trong', 'O'), ('Centella', 'B-NAME'), ('Asiatica', 'I-NAME'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('phục', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('hàng', 'I-BENEFITS'), ('rào', 'I-BENEFITS'), ('lipid', 'I-BENEFITS'), ('tự', 'I-BENEFITS'), ('nhiên', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('củng', 'O'), ('cố', 'O'), ('lớp', 'O'), ('màng', 'O'), ('bảo', 'O'), ('vệ', 'O'), ('này', 'O'), ('để', 'O'), ('giữ', 'O'), ('nước', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('hơn', 'O')]
# [('Các', 'O'), ('loại', 'O'), ('rau', 'B-ORIGIN'), ('củ', 'I-ORIGIN'), ('quả', 'I-ORIGIN'), ('là', 'O'), ('nguồn', 'O'), ('bổ', 'O'), ('sung', 'O'), ('vitamin', 'B-NAME'), ('E', 'I-NAME'), ('tự', 'O'), ('nhiên', 'O'), ('mang', 'O'), ('lại', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('cao', 'O'), ('nhất', 'O')]
# [('Công', 'O'), ('thức', 'O'), ('phân', 'O'), ('tử', 'O'), ('của', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('được', 'O'), ('xem', 'O'), ('như', 'O'), ('một', 'O'), ('trong', 'O'), ('những', 'O'), ('yếu', 'O'), ('tố', 'O'), ('quan', 'O'), ('trọng', 'O'), ('quyết', 'O'), ('định', 'O'), ('vẻ', 'O'), ('tươi', 'O'), ('trẻ', 'O'), ('của', 'O'), ('làn', 'O'), ('da', 'O')]
# [('Không', 'O'), ('chỉ', 'O'), ('vậy', 'O'), ('Gluconolactone', 'B-INCI'), ('còn', 'O'), ('có', 'O'), ('nguồn', 'I-ORIGIN'), ('gốc', 'I-ORIGIN'), ('tự', 'I-ORIGIN'), ('nhiên', 'I-ORIGIN'), ('thường', 'O'), ('được', 'O'), ('tìm', 'O'), ('thấy', 'O'), ('trong', 'O'), ('mật', 'B-ORIGIN'), ('ong', 'I-ORIGIN'), ('trái', 'B-ORIGIN'), ('cây', 'I-ORIGIN'), ('hoặc', 'O'), ('sản', 'O'), ('xuất', 'O'), ('thông', 'O'), ('qua', 'O'), ('quá', 'B-ORIGIN'), ('trình', 'I-ORIGIN'), ('lên', 'I-ORIGIN'), ('men', 'I-ORIGIN'), ('ngô', 'I-ORIGIN')]
# [('Vai', 'O'), ('trò', 'O'), ('quan', 'O'), ('trọng', 'O'), ('của', 'O'), ('Kojic', 'B-NAME'), ('acid', 'I-NAME'), ('là', 'O'), ('điều', 'O'), ('trị', 'O'), ('nám', 'B-SKIN_CONCERNS'), ('tàn', 'B-SKIN_CONCERNS'), ('nhang', 'I-SKIN_CONCERNS'), ('và', 'O'), ('đồi', 'B-SKIN_CONCERNS'), ('mồi', 'I-SKIN_CONCERNS')]
# [('Hỗ', 'O'), ('trợ', 'O'), ('tẩy', 'O'), ('tế', 'O'), ('bào', 'O'), ('da', 'O'), ('chết', 'O'), ('Allantoin', 'B-INCI'), ('giúp', 'O'), ('tẩy', 'B-BENEFITS'), ('tế', 'I-BENEFITS'), ('bào', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('chết', 'I-BENEFITS'), ('điều', 'B-BENEFITS'), ('trị', 'I-BENEFITS'), ('các', 'I-BENEFITS'), ('tình', 'I-BENEFITS'), ('trạng', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('cóc', 'I-BENEFITS'), ('làm', 'O'), ('bong', 'B-BENEFITS'), ('đi', 'I-BENEFITS'), ('lớp', 'I-BENEFITS'), ('tế', 'I-BENEFITS'), ('bào', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('chết', 'I-BENEFITS')]
# [('Retinol', 'B-NAME'), ('bên', 'O'), ('cạnh', 'O'), ('đó', 'O'), ('còn', 'O'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('ức', 'B-BENEFITS'), ('chế', 'I-BENEFITS'), ('sản', 'I-BENEFITS'), ('sinh', 'I-BENEFITS'), ('tế', 'I-BENEFITS'), ('bào', 'I-BENEFITS'), ('sắc', 'I-BENEFITS'), ('tố', 'I-BENEFITS'), ('Melanin', 'I-BENEFITS'), ('là', 'O'), ('nguyên', 'O'), ('nhân', 'O'), ('gây', 'O'), ('ra', 'O'), ('tình', 'O'), ('trạng', 'O'), ('nám', 'B-SKIN_CONCERNS'), ('và', 'O'), ('tàn', 'B-SKIN_CONCERNS'), ('nhang', 'I-SKIN_CONCERNS'), ('Điều', 'O'), ('này', 'O'), ('giúp', 'O'), ('ngăn', 'O'), ('ngừa', 'O'), ('vấn', 'O'), ('đề', 'O'), ('tăng', 'B-SKIN_CONCERNS'), ('sắc', 'I-SKIN_CONCERNS'), ('tố', 'I-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('xóa', 'B-BENEFITS'), ('mờ', 'I-BENEFITS'), ('sạm', 'I-BENEFITS'), ('nám', 'I-BENEFITS'), ('tàn', 'I-BENEFITS'), ('nhang', 'I-BENEFITS'), ('hay', 'O'), ('các', 'O'), ('đốm', 'O'), ('nâu', 'O'), ('các', 'O'), ('vết', 'O'), ('thâm', 'O'), ('cứng', 'O'), ('đầu', 'O'), ('do', 'O'), ('mụn', 'O'), ('gây', 'O'), ('ra', 'O')]
# [('Tóm', 'O'), ('lại', 'O'), ('theo', 'O'), ('nghiên', 'O'), ('cứu', 'O'), ('thì', 'O'), ('thành', 'O'), ('phần', 'O'), ('Glycerin', 'B-NAME'), ('rất', 'O'), ('tốt', 'O'), ('cho', 'O'), ('da', 'O')]
# [('Glycolic', 'B-INCI'), ('acid', 'I-INCI'), ('phù', 'O'), ('hợp', 'O'), ('với', 'O'), ('tất', 'B-SKIN_CONCERNS'), ('cả', 'I-SKIN_CONCERNS'), ('các', 'I-SKIN_CONCERNS'), ('loại', 'I-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS')]
# [('Cụ', 'O'), ('thể', 'O'), ('là', 'O'), ('Copper', 'B-INCI'), ('Peptide', 'I-INCI'), ('hay', 'O'), ('có', 'O'), ('tên', 'O'), ('khác', 'O'), ('là', 'O'), ('Peptide', 'B-NAME'), ('đồng', 'O'), ('được', 'O'), ('chứng', 'O'), ('minh', 'O'), ('có', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('trong', 'O'), ('việc', 'O'), ('phục', 'O'), ('hồi', 'O'), ('và', 'O'), ('cải', 'O'), ('thiện', 'O'), ('độ', 'O'), ('săn', 'O'), ('chắc', 'O'), ('làn', 'O'), ('da', 'O')]
# [('Hiệu', 'O'), ('quả', 'O'), ('chống', 'B-BENEFITS'), ('oxy', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('của', 'O'), ('PHA', 'B-NAME'), ('đã', 'O'), ('được', 'O'), ('ghi', 'O'), ('nhận', 'O'), ('tương', 'O'), ('đương', 'O'), ('với', 'O'), ('các', 'O'), ('thành', 'O'), ('phần', 'O'), ('kinh', 'O'), ('điển', 'O'), ('như', 'O'), ('Vitamin', 'O'), ('C', 'O'), ('và', 'O'), ('Vitamin', 'O'), ('E', 'O')]
# [('Houttuynia', 'B-NAME'), ('Cordata', 'I-NAME'), ('Extract', 'I-NAME'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('cảm', 'I-BENEFITS'), ('giác', 'I-BENEFITS'), ('thông', 'I-BENEFITS'), ('thoáng', 'I-BENEFITS'), ('cho', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('dầu', 'I-BENEFITS'), ('vào', 'O'), ('những', 'O'), ('ngày', 'O'), ('ẩm', 'O'), ('cao', 'O')]
# [('Nhiều', 'O'), ('bác', 'O'), ('sĩ', 'O'), ('da', 'O'), ('liễu', 'O'), ('xem', 'O'), ('Adapalene', 'B-NAME'), ('như', 'O'), ('lựa', 'O'), ('chọn', 'O'), ('retinoid', 'O'), ('êm', 'O'), ('hơn', 'O'), ('cho', 'O'), ('những', 'O'), ('ai', 'O'), ('có', 'O'), ('làn', 'B-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('dễ', 'I-SKIN_CONCERNS'), ('kích', 'I-SKIN_CONCERNS'), ('ứng', 'I-SKIN_CONCERNS')]
# [('Ngăn', 'O'), ('ngừa', 'O'), ('mụn', 'O'), ('Với', 'O'), ('kích', 'O'), ('thước', 'O'), ('phân', 'O'), ('tử', 'O'), ('lớn', 'O'), ('so', 'O'), ('với', 'O'), ('các', 'O'), ('AHA', 'B-NAME'), ('khác', 'O'), ('Mandelic', 'B-INCI'), ('Acid', 'I-INCI'), ('được', 'O'), ('sử', 'O'), ('dụng', 'O'), ('trong', 'O'), ('việc', 'O'), ('ngăn', 'B-BENEFITS'), ('ngừa', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('trứng', 'I-BENEFITS'), ('cá', 'I-BENEFITS'), ('giúp', 'O'), ('đẩy', 'B-BENEFITS'), ('lùi', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('mủ', 'I-BENEFITS'), ('viêm', 'I-BENEFITS'), ('mụn', 'O'), ('sẩn', 'O'), ('từ', 'O'), ('nhẹ', 'O'), ('đến', 'O'), ('trung', 'O'), ('bình', 'O'), ('nhờ', 'O'), ('vào', 'O'), ('tác', 'O'), ('dụng', 'O'), ('tiêu', 'O'), ('sừng', 'O'), ('chống', 'B-BENEFITS'), ('viêm', 'I-BENEFITS'), ('và', 'O'), ('tiêu', 'B-BENEFITS'), ('mụn', 'I-BENEFITS')]
# [('Do', 'O'), ('đó', 'O'), ('Beta', 'B-NAME'), ('Glucan', 'I-NAME'), ('được', 'O'), ('dùng', 'O'), ('nhiều', 'O'), ('trong', 'O'), ('mỹ', 'O'), ('phẩm', 'O'), ('với', 'O'), ('mục', 'O'), ('đích', 'O'), ('dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('hoàn', 'O'), ('hảo', 'O')]
# [('Resveratrol', 'B-NAME'), ('là', 'O'), ('hoạt', 'O'), ('chất', 'O'), ('chống', 'B-BENEFITS'), ('oxy', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('mang', 'O'), ('lại', 'O'), ('nhiều', 'O'), ('lợi', 'O'), ('ích', 'O'), ('đối', 'O'), ('với', 'O'), ('làn', 'O'), ('da', 'O'), ('và', 'O'), ('sức', 'O'), ('khỏe', 'O'), ('tổng', 'O'), ('thể', 'O')]
# [('Cũng', 'O'), ('bởi', 'O'), ('quá', 'O'), ('trình', 'O'), ('giải', 'O'), ('phóng', 'O'), ('thủy', 'O'), ('phân', 'O'), ('glucoside', 'B-NAME'), ('diễn', 'O'), ('ra', 'O'), ('chậm', 'O'), ('rãi', 'O'), ('nên', 'O'), ('Arbutin', 'B-NAME'), ('ít', 'O'), ('gây', 'O'), ('kích', 'O'), ('ứng', 'O'), ('hơn', 'O'), ('so', 'O'), ('với', 'O'), ('thành', 'O'), ('phần', 'O'), ('Hydroquinone', 'B-NAME')]
# [('Lựa', 'O'), ('chọn', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('có', 'O'), ('nồng', 'O'), ('độ', 'O'), ('Niacinamide', 'B-NAME'), ('phù', 'O'), ('hợp', 'O'), ('với', 'O'), ('da', 'O'), ('giúp', 'B-BENEFITS'), ('hạn', 'I-BENEFITS'), ('chế', 'I-BENEFITS'), ('tình', 'I-BENEFITS'), ('trạng', 'I-BENEFITS'), ('kích', 'I-BENEFITS'), ('ứng', 'I-BENEFITS'), ('có', 'O'), ('thể', 'O'), ('xảy', 'O'), ('da', 'O')]
# [('Các', 'O'), ('chuyên', 'O'), ('gia', 'O'), ('công', 'O'), ('thức', 'O'), ('mỹ', 'O'), ('phẩm', 'O'), ('đánh', 'O'), ('giá', 'O'), ('Adenosine', 'B-NAME'), ('có', 'O'), ('lợi', 'O'), ('ích', 'O'), ('nổi', 'O'), ('bật', 'O'), ('khi', 'O'), ('kết', 'O'), ('hợp', 'O'), ('cùng', 'O'), ('Retinol', 'O'), ('để', 'O'), ('giảm', 'O'), ('kích', 'O'), ('ứng', 'O')]
# [('Cây', 'B-NAME'), ('phỉ', 'I-NAME'), ('cũng', 'O'), ('đã', 'O'), ('được', 'O'), ('chứng', 'O'), ('minh', 'O'), ('là', 'O'), ('an', 'O'), ('toàn', 'O'), ('khi', 'O'), ('thoa', 'O'), ('lên', 'O'), ('da', 'B-SKIN_CONCERNS'), ('đầu', 'I-SKIN_CONCERNS')]
# [('Nhờ', 'O'), ('đặc', 'O'), ('tính', 'O'), ('kháng', 'B-BENEFITS'), ('viêm', 'I-BENEFITS'), ('kháng', 'B-BENEFITS'), ('khuẩn', 'I-BENEFITS'), ('sulfur', 'B-NAME'), ('còn', 'O'), ('loại', 'O'), ('bỏ', 'O'), ('vi', 'O'), ('khuẩn', 'O'), ('mụn', 'O'), ('nằm', 'O'), ('ẩn', 'O'), ('sâu', 'O'), ('trong', 'O'), ('lỗ', 'O'), ('chân', 'O'), ('lông', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('ngăn', 'B-BENEFITS'), ('ngừa', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('hình', 'O'), ('thành', 'O'), ('trở', 'O'), ('lại', 'O')]
# [('Kem', 'O'), ('Urea', 'B-NAME'), ('hoạt', 'O'), ('động', 'O'), ('như', 'O'), ('một', 'O'), ('chất', 'O'), ('giúp', 'O'), ('làm', 'B-BENEFITS'), ('mềm', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('có', 'O'), ('tác', 'O'), ('dụng', 'O'), ('loại', 'B-BENEFITS'), ('bỏ', 'I-BENEFITS'), ('phần', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('chết', 'I-BENEFITS'), ('giúp', 'O'), ('da', 'O'), ('bạn', 'O'), ('tươi', 'O'), ('sáng', 'O'), ('hơn', 'O')]
# [('Công', 'O'), ('thức', 'O'), ('chứa:', 'O'), ('Sản', 'O'), ('phẩm', 'O'), ('phù', 'O'), ('hợp', 'O'), ('với', 'O'), ('mọi', 'B-SKIN_CONCERNS'), ('loại', 'I-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('đặc', 'O'), ('biệt', 'O'), ('làn', 'B-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('nhạy', 'I-SKIN_CONCERNS'), ('cảm', 'I-SKIN_CONCERNS'), ('gặp', 'O'), ('phải', 'O'), ('những', 'O'), ('dấu', 'O'), ('hiệu', 'O'), ('lão', 'O'), ('hóa', 'O'), ('nghiêm', 'O'), ('trọng', 'O')]
# [('Người', 'O'), ('bị', 'O'), ('tình', 'O'), ('trạng', 'O'), ('da', 'B-SKIN_CONCERNS'), ('dễ', 'I-SKIN_CONCERNS'), ('viêm', 'I-SKIN_CONCERNS'), ('đỏ', 'I-SKIN_CONCERNS'), ('có', 'O'), ('thể', 'O'), ('tìm', 'O'), ('thấy', 'O'), ('EGCG', 'B-NAME'), ('trong', 'O'), ('các', 'O'), ('loại', 'O'), ('gel', 'O'), ('làm', 'O'), ('dịu', 'O'), ('chuyên', 'O'), ('dụng', 'O')]
# [('Là', 'O'), ('thành', 'O'), ('phần', 'O'), ('nổi', 'O'), ('trội', 'O'), ('trong', 'O'), ('các', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('cải', 'O'), ('thiện', 'O'), ('vấn', 'O'), ('đề', 'O'), ('về', 'O'), ('lỗ', 'O'), ('chân', 'O'), ('lông', 'O'), ('Niacinamide', 'B-NAME'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('làm', 'B-BENEFITS'), ('mờ', 'I-BENEFITS'), ('sẹo', 'I-BENEFITS'), ('thâm', 'I-BENEFITS'), ('sau', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('khắc', 'O'), ('phục', 'O'), ('tình', 'O'), ('trạng', 'O'), ('da', 'B-SKIN_CONCERNS'), ('có', 'I-SKIN_CONCERNS'), ('dấu', 'I-SKIN_CONCERNS'), ('hiệu', 'I-SKIN_CONCERNS'), ('mẩn', 'I-SKIN_CONCERNS'), ('đỏ', 'I-SKIN_CONCERNS'), ('dầu', 'B-SKIN_CONCERNS'), ('thừa', 'I-SKIN_CONCERNS'), ('hay', 'O'), ('sợi', 'B-SKIN_CONCERNS'), ('bã', 'I-SKIN_CONCERNS'), ('nhờn', 'I-SKIN_CONCERNS'), ('dày', 'I-SKIN_CONCERNS'), ('đặc', 'I-SKIN_CONCERNS'), ('là', 'O'), ('những', 'O'), ('nguyên', 'O'), ('nhân', 'O'), ('chính', 'O'), ('gây', 'O'), ('ra', 'O'), ('mụn', 'O')]
# [('Madecassoside', 'B-NAME'), ('nổi', 'O'), ('bật', 'O'), ('nhờ', 'O'), ('khả', 'O'), ('năng', 'O'), ('làm', 'B-BENEFITS'), ('dịu', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('và', 'O'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('phục', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('lớp', 'I-BENEFITS'), ('biểu', 'I-BENEFITS'), ('bì', 'I-BENEFITS'), ('khi', 'O'), ('da', 'B-SKIN_CONCERNS'), ('bị', 'I-SKIN_CONCERNS'), ('kích', 'I-SKIN_CONCERNS'), ('ứng', 'I-SKIN_CONCERNS')]
# [('Phục', 'O'), ('hồi', 'O'), ('hàng', 'O'), ('rào', 'O'), ('bảo', 'O'), ('vệ', 'O'), ('da', 'O'), ('Vitamin', 'B-NAME'), ('B5', 'I-NAME'), ('thúc', 'B-BENEFITS'), ('đẩy', 'I-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('tái', 'I-BENEFITS'), ('tạo', 'I-BENEFITS'), ('tế', 'I-BENEFITS'), ('bào', 'I-BENEFITS'), ('giúp', 'O'), ('khôi', 'B-BENEFITS'), ('phục', 'I-BENEFITS'), ('và', 'I-BENEFITS'), ('củng', 'I-BENEFITS'), ('cố', 'I-BENEFITS'), ('hàng', 'I-BENEFITS'), ('rào', 'I-BENEFITS'), ('bảo', 'I-BENEFITS'), ('vệ', 'I-BENEFITS'), ('tự', 'I-BENEFITS'), ('nhiên', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('da', 'I-BENEFITS')]
# [('da', 'B-SKIN_CONCERNS'), ('nhạy', 'I-SKIN_CONCERNS'), ('cảm', 'I-SKIN_CONCERNS'), ('dễ', 'B-SKIN_CONCERNS'), ('kích', 'I-SKIN_CONCERNS'), ('ứng', 'I-SKIN_CONCERNS'), ('đỏ', 'B-SKIN_CONCERNS'), ('rát', 'I-SKIN_CONCERNS'), ('Tuy', 'O'), ('vậy', 'O'), ('dù', 'O'), ('dầu', 'O'), ('squalane', 'B-NAME'), ('là', 'O'), ('một', 'O'), ('sự', 'O'), ('lựa', 'O'), ('chọn', 'O'), ('tuyệt', 'O'), ('vời', 'O'), ('cho', 'O'), ('mọi', 'O'), ('loại', 'O'), ('da', 'O'), ('trước', 'O'), ('khi', 'O'), ('sử', 'O'), ('dụng', 'O'), ('người', 'O'), ('dùng', 'O'), ('nên', 'O'), ('tự', 'O'), ('mình', 'O'), ('thử', 'O'), ('để', 'O'), ('xem', 'O'), ('phản', 'O'), ('ứng', 'O'), ('thực', 'O'), ('sự', 'O'), ('của', 'O'), ('thành', 'O'), ('phần', 'O'), ('này', 'O'), ('đối', 'O'), ('với', 'O'), ('làn', 'O'), ('da', 'O'), ('bản', 'O'), ('thân', 'O'), ('như', 'O'), ('thế', 'O'), ('nào', 'O'), ('phòng', 'O'), ('ngừa', 'O'), ('tối', 'O'), ('đa', 'O'), ('nguy', 'O'), ('cơ', 'O'), ('bị', 'O'), ('kích', 'O'), ('ứng', 'O')]
# [('Vitamin', 'B-NAME'), ('E', 'I-NAME'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('là', 'O'), ('việc', 'O'), ('sử', 'O'), ('dụng', 'O'), ('vitamin', 'O'), ('E', 'O'), ('một', 'O'), ('chất', 'O'), ('chống', 'B-BENEFITS'), ('oxy', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('mạnh', 'O'), ('mẽ', 'O'), ('để', 'O'), ('dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('sâu', 'I-BENEFITS'), ('chống', 'B-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('làm', 'O'), ('mờ', 'I-BENEFITS'), ('thâm', 'I-BENEFITS'), ('nám', 'I-BENEFITS'), ('sẹo', 'B-BENEFITS'), ('mụn', 'I-BENEFITS'), ('và', 'O'), ('phục', 'O'), ('hồi', 'O'), ('da', 'B-SKIN_CONCERNS'), ('khô', 'I-SKIN_CONCERNS'), ('bong', 'I-SKIN_CONCERNS'), ('tróc', 'I-SKIN_CONCERNS'), ('giúp', 'B-BENEFITS'), ('da', 'I-BENEFITS'), ('khỏe', 'I-BENEFITS'), ('mạnh', 'I-BENEFITS'), ('mịn', 'I-BENEFITS'), ('màng', 'I-BENEFITS'), ('và', 'I-BENEFITS'), ('tươi', 'I-BENEFITS'), ('trẻ', 'I-BENEFITS')]
# [('Nhờ', 'O'), ('công', 'O'), ('dụng', 'O'), ('cấp', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('và', 'O'), ('củng', 'B-BENEFITS'), ('cố', 'I-BENEFITS'), ('hàng', 'I-BENEFITS'), ('rào', 'I-BENEFITS'), ('bảo', 'I-BENEFITS'), ('vệ', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('Urea', 'B-NAME'), ('trở', 'O'), ('thành', 'O'), ('một', 'O'), ('trong', 'O'), ('những', 'O'), ('biện', 'O'), ('pháp', 'O'), ('làm', 'B-BENEFITS'), ('dịu', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('khá', 'O'), ('hiệu', 'O'), ('quả', 'O')]
# [('Nhiều', 'O'), ('dòng', 'O'), ('cream', 'O'), ('phục', 'O'), ('hồi', 'O'), ('sử', 'O'), ('dụng', 'O'), ('Madecassoside', 'B-NAME'), ('nhằm', 'O'), ('giải', 'O'), ('quyết', 'O'), ('tình', 'O'), ('trạng', 'O'), ('da', 'B-SKIN_CONCERNS'), ('tổn', 'I-SKIN_CONCERNS'), ('thương', 'I-SKIN_CONCERNS'), ('sau', 'I-SKIN_CONCERNS'), ('khi', 'I-SKIN_CONCERNS'), ('dùng', 'I-SKIN_CONCERNS'), ('treatment', 'I-SKIN_CONCERNS'), ('mạnh', 'I-SKIN_CONCERNS')]
# [('Bakuchiol', 'B-NAME'), ('thường', 'O'), ('được', 'O'), ('quảng', 'O'), ('cáo', 'O'), ('là', 'O'), ('sự', 'O'), ('thay', 'O'), ('thế', 'O'), ('cho', 'O'), ('Retinol', 'B-NAME'), ('giúp', 'O'), ('giảm', 'O'), ('đi', 'O'), ('các', 'O'), ('dấu', 'O'), ('hiệu', 'O'), ('nhạy', 'O'), ('cảm', 'O'), ('mà', 'O'), ('một', 'O'), ('số', 'O'), ('người', 'O'), ('gặp', 'O'), ('phải', 'O'), ('từ', 'O'), ('Retinol', 'B-NAME')]
# [('Việc', 'O'), ('thiếu', 'O'), ('hụt', 'O'), ('Cholesterol', 'B-NAME'), ('có', 'O'), ('thể', 'O'), ('khiến', 'O'), ('làn', 'B-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('dễ', 'I-SKIN_CONCERNS'), ('bị', 'I-SKIN_CONCERNS'), ('khô', 'I-SKIN_CONCERNS'), ('và', 'O'), ('tổn', 'O'), ('thương', 'O'), ('hơn', 'O')]
# [('Chính', 'O'), ('vì', 'O'), ('vậy', 'O'), ('Betaine', 'B-NAME'), ('thường', 'O'), ('xuất', 'O'), ('hiện', 'O'), ('trong', 'O'), ('các', 'O'), ('loại', 'O'), ('kem', 'O'), ('và', 'O'), ('serum', 'O'), ('chống', 'B-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('giúp', 'I-BENEFITS'), ('cải', 'I-BENEFITS'), ('thiện', 'I-BENEFITS'), ('kết', 'I-BENEFITS'), ('cấu', 'I-BENEFITS'), ('và', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('đồng', 'O'), ('thời', 'O'), ('mang', 'B-BENEFITS'), ('lại', 'I-BENEFITS'), ('làn', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('khỏe', 'I-BENEFITS'), ('mạnh', 'I-BENEFITS'), ('căng', 'I-BENEFITS'), ('mịn', 'I-BENEFITS')]
# [('Công', 'O'), ('dụng', 'O'), ('của', 'O'), ('Peptide', 'B-NAME'), ('cho', 'O'), ('da', 'O'), ('có', 'O'), ('thể', 'O'), ('kể', 'O'), ('đến', 'O'), ('là:', 'O'), ('Tác', 'O'), ('dụng', 'O'), ('của', 'O'), ('Peptide', 'O'), ('đối', 'O'), ('với', 'O'), ('da', 'O'), ('đầu', 'O'), ('tiên', 'O'), ('và', 'O'), ('quan', 'O'), ('trọng', 'O'), ('nhất', 'O'), ('là', 'O'), ('khả', 'O'), ('năng', 'O'), ('củng', 'B-BENEFITS'), ('cố', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('da', 'I-BENEFITS')]
# [('Với', 'O'), ('cơ', 'O'), ('chế', 'O'), ('"nới', 'O'), ('lỏng"', 'O'), ('liên', 'O'), ('kết', 'O'), ('giữa', 'O'), ('các', 'O'), ('tế', 'O'), ('bào', 'O'), ('sừng', 'O'), ('hoạt', 'O'), ('chất', 'O'), ('này', 'O'), ('giúp', 'O'), ('bề', 'O'), ('mặt', 'O'), ('da', 'O'), ('trở', 'O'), ('nên', 'O'), ('mịn', 'O'), ('màng', 'O'), ('sáng', 'O'), ('khỏe', 'O'), ('mà', 'O'), ('không', 'O'), ('gây', 'O'), ('bong', 'O'), ('tróc', 'O'), ('hay', 'O'), ('khô', 'O'), ('rát', 'O'), ('như', 'O'), ('một', 'O'), ('số', 'O'), ('AHA', 'O'), ('mạnh', 'O')]
# [('Adapalene', 'B-NAME'), ('là', 'O'), ('retinoid', 'O'), ('hiếm', 'O'), ('hoi', 'O'), ('có', 'B-BENEFITS'), ('tính', 'I-BENEFITS'), ('bền', 'I-BENEFITS'), ('vững', 'I-BENEFITS'), ('với', 'I-BENEFITS'), ('oxy', 'I-BENEFITS'), ('và', 'I-BENEFITS'), ('ánh', 'I-BENEFITS'), ('sáng', 'I-BENEFITS'), ('rất', 'O'), ('thuận', 'O'), ('tiện', 'O'), ('khi', 'O'), ('sử', 'O'), ('dụng', 'O'), ('lâu', 'O'), ('dài', 'O')]
# [('Với', 'O'), ('khả', 'O'), ('năng', 'O'), ('thẩm', 'O'), ('thấu', 'O'), ('sâu', 'O'), ('vào', 'O'), ('lỗ', 'O'), ('chân', 'O'), ('lông', 'O'), ('và', 'O'), ('loại', 'O'), ('bỏ', 'O'), ('bã', 'O'), ('nhờn', 'O'), ('Axit', 'I-INCI'), ('Salicylic', 'I-INCI'), ('mang', 'O'), ('lại', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('làm', 'B-BENEFITS'), ('sạch', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('giảm', 'B-BENEFITS'), ('mụn', 'I-BENEFITS'), ('rõ', 'O'), ('rệt', 'O')]
# [('Trong', 'O'), ('mỹ', 'O'), ('phẩm', 'O'), ('Tranexamic', 'B-INCI'), ('Acid', 'I-INCI'), ('thường', 'O'), ('tồn', 'O'), ('tại', 'O'), ('dưới', 'O'), ('nhiều', 'O'), ('dạng', 'O'), ('chiết', 'O'), ('xuất', 'O'), ('khác', 'O'), ('nhau', 'O'), ('như', 'O'), ('Tranexamic', 'O'), ('Acid', 'O'), ('hay', 'O'), ('m-tranexamic', 'B-NAME'), ('acid', 'I-NAME')]
# [('Sau', 'O'), ('đó', 'O'), ('lượng', 'O'), ('HA', 'O'), ('sẽ', 'O'), ('được', 'O'), ('tự', 'B-ORIGIN'), ('sản', 'I-ORIGIN'), ('sinh', 'I-ORIGIN'), ('lại', 'I-ORIGIN'), ('nhờ', 'I-ORIGIN'), ('một', 'I-ORIGIN'), ('số', 'I-ORIGIN'), ('enzyme', 'I-ORIGIN'), ('đặc', 'I-ORIGIN'), ('biệt', 'I-ORIGIN')]
# [('Glycerin', 'B-NAME'), ('giúp', 'B-BENEFITS'), ('dưỡng', 'I-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('và', 'O'), ('làm', 'B-BENEFITS'), ('mềm', 'I-BENEFITS'), ('cho', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('khô', 'O'), ('Bởi', 'O'), ('Glycerine', 'B-NAME'), ('có', 'O'), ('tính', 'O'), ('hút', 'O'), ('ẩm', 'O'), ('nên', 'O'), ('nó', 'O'), ('sẽ', 'O'), ('hút', 'O'), ('nước', 'O'), ('từ', 'O'), ('không', 'O'), ('khí', 'O'), ('để', 'O'), ('giữ', 'B-BENEFITS'), ('cho', 'I-BENEFITS'), ('làn', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('luôn', 'I-BENEFITS'), ('căng', 'I-BENEFITS'), ('mịn', 'I-BENEFITS'), ('hạn', 'B-BENEFITS'), ('chế', 'I-BENEFITS'), ('tình', 'I-BENEFITS'), ('trạng', 'I-BENEFITS'), ('thoát', 'I-BENEFITS'), ('hơi', 'I-BENEFITS'), ('nước', 'I-BENEFITS'), ('giảm', 'B-BENEFITS'), ('thiểu', 'I-BENEFITS'), ('sự', 'I-BENEFITS'), ('mất', 'I-BENEFITS'), ('nước', 'I-BENEFITS'), ('ở', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('duy', 'B-BENEFITS'), ('trì', 'I-BENEFITS'), ('cân', 'I-BENEFITS'), ('bằng', 'I-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('hiệu', 'I-BENEFITS'), ('quả', 'O')]
# [('Khi', 'O'), ('sử', 'O'), ('dụng', 'O'), ('Arbutin', 'B-NAME'), ('để', 'O'), ('làm', 'O'), ('đẹp', 'O'), ('nên', 'O'), ('chú', 'O'), ('ý', 'O'), ('tới', 'O'), ('liều', 'O'), ('lượng', 'O'), ('và', 'O'), ('cách', 'O'), ('sử', 'O'), ('dụng', 'O'), ('đồng', 'O'), ('thời', 'O'), ('nên', 'O'), ('test', 'O'), ('trước', 'O'), ('xem', 'O'), ('mình', 'O'), ('có', 'O'), ('bị', 'O'), ('dị', 'O'), ('ứng', 'O'), ('với', 'O'), ('thành', 'O'), ('phần', 'O'), ('này', 'O'), ('hay', 'O'), ('không', 'O')]
# [('Dưới', 'O'), ('đây', 'O'), ('là', 'O'), ('những', 'O'), ('công', 'O'), ('dụng', 'O'), ('nổi', 'O'), ('bật', 'O'), ('đã', 'O'), ('được', 'O'), ('nghiên', 'O'), ('cứu:', 'O'), ('Zinc', 'B-NAME'), ('PCA', 'I-NAME'), ('ức', 'B-BENEFITS'), ('chế', 'I-BENEFITS'), ('hoạt', 'I-BENEFITS'), ('động', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('enzyme', 'I-BENEFITS'), ('5-alpha', 'I-BENEFITS'), ('reductase', 'I-BENEFITS'), ('giảm', 'B-BENEFITS'), ('sản', 'I-BENEFITS'), ('sinh', 'I-BENEFITS'), ('bã', 'I-BENEFITS'), ('nhờn', 'I-BENEFITS')]
# [('Chống', 'O'), ('lão', 'O'), ('hoá', 'O'), ('Ngoài', 'O'), ('vai', 'O'), ('trò', 'O'), ('tẩy', 'O'), ('tế', 'O'), ('bào', 'O'), ('chết', 'O'), ('Mandelic', 'B-INCI'), ('Acid', 'I-INCI'), ('còn', 'O'), ('có', 'O'), ('một', 'O'), ('“siêu', 'O'), ('năng', 'O'), ('lực”', 'O'), ('khác', 'O'), ('là', 'O'), ('chống', 'B-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('da', 'I-BENEFITS')]
# [('Resveratrol', 'B-NAME'), ('được', 'O'), ('tìm', 'O'), ('thấy', 'O'), ('nhiều', 'O'), ('nhất', 'O'), ('ở', 'O'), ('hạt', 'B-ORIGIN'), ('vỏ', 'B-ORIGIN'), ('quả', 'I-ORIGIN'), ('nho', 'I-ORIGIN'), ('và', 'O'), ('các', 'O'), ('loại', 'O'), ('quả', 'B-ORIGIN'), ('mọng', 'I-ORIGIN')]
# [('Một', 'O'), ('trong', 'O'), ('số', 'O'), ('đó', 'O'), ('là', 'O'), ('Zinc', 'B-NAME'), ('PCA', 'I-NAME'), ('–', 'O'), ('thành', 'O'), ('phần', 'O'), ('nổi', 'O'), ('bật', 'O'), ('trong', 'O'), ('nhiều', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('trị', 'O'), ('mụn', 'O'), ('kiềm', 'B-BENEFITS'), ('dầu', 'I-BENEFITS'), ('và', 'O'), ('phục', 'B-BENEFITS'), ('hồi', 'I-BENEFITS'), ('da', 'I-BENEFITS')]
# [('Tác', 'O'), ('dụng', 'O'), ('của', 'O'), ('cây', 'I-NAME'), ('phỉ', 'I-NAME'), ('là', 'O'), ('làm', 'O'), ('giảm', 'B-BENEFITS'), ('tình', 'I-BENEFITS'), ('trạng', 'I-BENEFITS'), ('viêm', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('cơ', 'I-BENEFITS'), ('bản', 'I-BENEFITS'), ('và', 'O'), ('làm', 'O'), ('cho', 'O'), ('các', 'O'), ('phản', 'O'), ('ứng', 'O'), ('phát', 'O'), ('ban', 'O'), ('xuất', 'O'), ('hiện', 'O'), ('hơn', 'O')]
# [('Centella', 'B-NAME'), ('Asiatica', 'I-NAME'), ('là', 'O'), ('một', 'O'), ('trong', 'O'), ('những', 'O'), ('thành', 'O'), ('phần', 'O'), ('phổ', 'O'), ('biến', 'O'), ('trong', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('dưỡng', 'O'), ('da', 'O'), ('đặc', 'O'), ('biệt', 'O'), ('là', 'O'), ('làn', 'B-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('nhạy', 'I-SKIN_CONCERNS'), ('cảm', 'I-SKIN_CONCERNS'), ('và', 'I-SKIN_CONCERNS'), ('dễ', 'I-SKIN_CONCERNS'), ('kích', 'I-SKIN_CONCERNS'), ('ứng', 'I-SKIN_CONCERNS')]
# [('Chính', 'O'), ('nhờ', 'O'), ('những', 'O'), ('lợi', 'O'), ('ích', 'O'), ('này', 'O'), ('Linoleic', 'B-NAME'), ('Acid', 'I-NAME'), ('thường', 'O'), ('được', 'O'), ('ứng', 'O'), ('dụng', 'O'), ('trong', 'O'), ('các', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('đặc', 'O'), ('biệt', 'O'), ('là', 'O'), ('kem', 'O'), ('dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('nhằm', 'O'), ('củng', 'B-BENEFITS'), ('cố', 'I-BENEFITS'), ('hàng', 'I-BENEFITS'), ('rào', 'I-BENEFITS'), ('bảo', 'I-BENEFITS'), ('vệ', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('cải', 'B-BENEFITS'), ('thiện', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('và', 'O'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('phục', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('sau', 'I-BENEFITS'), ('tổn', 'I-BENEFITS'), ('thương', 'I-BENEFITS')]
# [('Adapalene', 'B-NAME'), ('kích', 'B-BENEFITS'), ('thích', 'I-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('đổi', 'I-BENEFITS'), ('mới', 'I-BENEFITS'), ('tế', 'I-BENEFITS'), ('bào', 'I-BENEFITS'), ('nên', 'O'), ('cũng', 'O'), ('cải', 'B-BENEFITS'), ('thiện', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('xỉn', 'I-BENEFITS'), ('màu', 'I-BENEFITS'), ('sau', 'O'), ('mụn', 'O')]
# [('Dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('và', 'O'), ('làm', 'B-BENEFITS'), ('mềm', 'I-BENEFITS'), (':Cholesterol', 'O'), ('khóa', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('và', 'O'), ('mang', 'O'), ('lại', 'O'), ('cho', 'O'), ('làn', 'O'), ('da', 'O'), ('vẻ', 'O'), ('căng', 'O'), ('bóng', 'O'), ('không', 'O'), ('nhờn', 'O')]
# [('Ngoài', 'O'), ('ra', 'O'), ('Urea', 'B-NAME'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('thẩm', 'O'), ('thấu', 'O'), ('sâu', 'O'), ('vào', 'O'), ('các', 'O'), ('tầng', 'O'), ('da', 'O'), ('mang', 'O'), ('lại', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('tốt', 'O'), ('hơn', 'O')]
# [('Các', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('chứa', 'O'), ('Sulfur', 'B-NAME'), ('thường', 'O'), ('nhắm', 'O'), ('đến', 'O'), ('tình', 'O'), ('trạng', 'O'), ('mụn', 'B-SKIN_CONCERNS'), ('đầu', 'I-SKIN_CONCERNS'), ('đen', 'I-SKIN_CONCERNS'), ('và', 'I-SKIN_CONCERNS'), ('đầu', 'I-SKIN_CONCERNS'), ('trắng', 'I-SKIN_CONCERNS'), ('ở', 'I-SKIN_CONCERNS'), ('vùng', 'I-SKIN_CONCERNS'), ('mũi', 'I-SKIN_CONCERNS'), ('và', 'I-SKIN_CONCERNS'), ('cằm', 'I-SKIN_CONCERNS')]
# [('Các', 'O'), ('công', 'O'), ('thức', 'O'), ('phục', 'O'), ('hồi', 'O'), ('da', 'O'), ('nhanh', 'O'), ('thường', 'O'), ('dùng', 'O'), ('Madecassoside', 'B-NAME'), ('để', 'O'), ('tăng', 'B-BENEFITS'), ('cường', 'I-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('tái', 'I-BENEFITS'), ('tạo', 'I-BENEFITS'), ('mô', 'I-BENEFITS'), ('tổn', 'I-BENEFITS'), ('thương', 'I-BENEFITS')]
# [('Các', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('dành', 'O'), ('cho', 'O'), ('da', 'B-SKIN_CONCERNS'), ('bong', 'I-SKIN_CONCERNS'), ('tróc', 'I-SKIN_CONCERNS'), ('sau', 'I-SKIN_CONCERNS'), ('peel', 'I-SKIN_CONCERNS'), ('hóa', 'I-SKIN_CONCERNS'), ('học', 'I-SKIN_CONCERNS'), ('hay', 'O'), ('bổ', 'O'), ('sung', 'O'), ('Madecassoside', 'B-NAME'), ('để', 'O'), ('làm', 'B-BENEFITS'), ('dịu', 'I-BENEFITS'), ('vùng', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('tổn', 'I-BENEFITS'), ('thương', 'I-BENEFITS')]
# [('Chiết', 'O'), ('xuất', 'O'), ('bột', 'B-NAME'), ('yến', 'I-NAME'), ('mạch', 'I-NAME'), ('mang', 'O'), ('lại', 'O'), ('tác', 'O'), ('dụng', 'O'), ('chống', 'I-BENEFITS'), ('viêm', 'I-BENEFITS'), ('và', 'O'), ('chống', 'B-BENEFITS'), ('oxy', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('bằng', 'O'), ('cách', 'O'), ('làm', 'O'), ('giảm', 'O'), ('sự', 'O'), ('hoạt', 'O'), ('động', 'O'), ('của', 'O'), ('chất', 'O'), ('xúc', 'O'), ('tiến', 'O'), ('NF-κB', 'O'), ('giảm', 'O'), ('tạo', 'O'), ('ROS', 'O'), ('và', 'O'), ('giảm', 'O'), ('sản', 'O'), ('xuất', 'O'), ('IL-8', 'O')]
# [('Retinal', 'B-NAME'), ('hay', 'O'), ('còn', 'O'), ('gọi', 'O'), ('là', 'O'), ('Retinaldehyde', 'B-INCI'), ('-', 'O'), ('thuộc', 'O'), ('nhóm', 'O'), ('-', 'O'), ('là', 'O'), ('một', 'O'), ('dẫn', 'B-ORIGIN'), ('xuất', 'I-ORIGIN'), ('của', 'I-ORIGIN'), ('Vitamin', 'I-ORIGIN'), ('A', 'I-ORIGIN'), ('có', 'O'), ('nguồn', 'O'), ('gốc', 'O'), ('từ', 'O'), ('tự', 'O'), ('nhiên', 'O'), ('trong', 'B-ORIGIN'), ('cơ', 'I-ORIGIN'), ('thể', 'I-ORIGIN'), ('và', 'O'), ('cũng', 'O'), ('có', 'O'), ('thể', 'O'), ('được', 'O'), ('tổng', 'B-ORIGIN'), ('hợp', 'I-ORIGIN'), ('từ', 'I-ORIGIN'), ('các', 'I-ORIGIN'), ('nguồn', 'I-ORIGIN'), ('thực', 'I-ORIGIN'), ('phẩm', 'I-ORIGIN'), ('quen', 'O'), ('thuộc', 'O'), ('như', 'O'), ('lòng', 'O'), ('đỏ', 'O'), ('trứng', 'O'), ('gan', 'O'), ('cũng', 'O'), ('như', 'O'), ('các', 'O'), ('loại', 'O'), ('rau', 'O'), ('có', 'O'), ('màu', 'O'), ('xanh', 'O'), ('đậm', 'O'), ('Được', 'O'), ('đánh', 'O'), ('giá', 'O'), ('là', 'O'), ('thành', 'O'), ('phần', 'O'), ('gần', 'O'), ('nhất', 'O'), ('với', 'O'), ('Retinoic', 'B-NAME'), ('Acid', 'I-NAME'), ('kê', 'O'), ('đơn', 'O'), ('Retinal', 'B-NAME'), ('đóng', 'O'), ('vai', 'O'), ('trò', 'O'), ('quan', 'O'), ('trọng', 'O'), ('trong', 'O'), ('việc', 'O'), ('giúp', 'O'), ('da', 'B-BENEFITS'), ('săn', 'I-BENEFITS'), ('chắc', 'I-BENEFITS'), ('đều', 'B-BENEFITS'), ('màu', 'I-BENEFITS'), ('mờ', 'B-BENEFITS'), ('nếp', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('cũng', 'O'), ('như', 'O'), ('kiểm', 'B-BENEFITS'), ('soát', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('trứng', 'I-BENEFITS'), ('cá', 'I-BENEFITS'), ('với', 'O'), ('cơ', 'O'), ('chế', 'O'), ('tăng', 'O'), ('tốc', 'O'), ('độ', 'O'), ('sừng', 'O'), ('hóa', 'O'), ('thúc', 'O'), ('đẩy', 'O'), ('quá', 'O'), ('trình', 'O'), ('sản', 'O'), ('sinh', 'O'), ('trên', 'O'), ('da', 'O'), ('Để', 'O'), ('phát', 'O'), ('huy', 'O'), ('được', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('tối', 'O'), ('đa', 'O'), ('Retinal', 'O'), ('sẽ', 'O'), ('thường', 'O'), ('chiếm', 'O'), ('hàm', 'O'), ('lượng', 'O'), ('rất', 'O'), ('ít', 'O'), ('từ', 'O'), ('0', 'O'), ('05%', 'O'), ('-', 'O'), ('0', 'O'), ('1%', 'O'), ('trong', 'O'), ('tổng', 'O'), ('định', 'O'), ('lượng', 'O'), ('sản', 'O'), ('phẩm', 'O')]
# [('Cụ', 'O'), ('thể', 'O'), ('như', 'O'), ('sau:', 'O'), ('Niacinamide', 'B-NAME'), ('trị', 'O'), ('mụn', 'O'), ('biểu', 'O'), ('hiện', 'O'), ('qua', 'O'), ('tác', 'O'), ('dụng', 'O'), ('nhờ', 'O'), ('đặc', 'O'), ('tính', 'O'), ('kháng', 'O'), ('viêm', 'O'), ('Kích', 'O'), ('thích', 'O'), ('tổng', 'O'), ('hợp', 'O'), ('protein', 'O'), ('K1', 'O'), ('và', 'O'), ('các', 'O'), ('collagen', 'O'), ('tốt', 'O'), ('cho', 'O'), ('da', 'O'), ('cải', 'O'), ('thiện', 'B-BENEFITS'), ('vẻ', 'I-BENEFITS'), ('ngoài', 'I-BENEFITS'), ('làn', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('căng', 'I-BENEFITS'), ('mịn', 'I-BENEFITS'), ('và', 'O'), ('trẻ', 'O'), ('trung', 'O'), ('hơn', 'O')]
# [('Gluconolactone', 'B-INCI'), ('là', 'O'), ('một', 'O'), ('loại', 'O'), ('Polyhydroxy', 'O'), ('Acid', 'O'), ('(PHA)', 'O'), ('thường', 'O'), ('được', 'O'), ('xem', 'O'), ('như', 'O'), ('“', 'O'), ('AHA', 'B-NAME'), ('thế', 'I-NAME'), ('hệ', 'I-NAME'), ('mới”', 'I-NAME'), ('hay', 'O'), ('“thế', 'O'), ('hệ', 'I-NAME'), ('thứ', 'I-NAME'), ('hai', 'I-NAME'), ('của', 'I-NAME'), ('AHA”', 'I-NAME')]
# [('Niacinamide', 'B-NAME'), ('được', 'O'), ('đánh', 'O'), ('giá', 'O'), ('là', 'O'), ('thành', 'O'), ('phần', 'O'), ('hiếm', 'O'), ('hoi', 'O'), ('mang', 'O'), ('lại', 'O'), ('nhiều', 'O'), ('lợi', 'O'), ('ích', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('đặc', 'O'), ('biệt', 'O'), ('các', 'O'), ('có', 'O'), ('thể', 'O'), ('xảy', 'O'), ('ra', 'O'), ('là', 'O'), ('không', 'O'), ('đáng', 'O'), ('kể', 'O'), ('và', 'O'), ('hoàn', 'O'), ('toàn', 'O'), ('có', 'O'), ('thể', 'O'), ('khắc', 'O'), ('phục', 'O'), ('dễ', 'O'), ('dàng', 'O'), ('Điều', 'O'), ('đó', 'O'), ('thuyết', 'O'), ('phục', 'O'), ('ngay', 'O'), ('cả', 'O'), ('những', 'O'), ('khách', 'O'), ('hàng', 'O'), ('khó', 'O'), ('tính', 'O'), ('hay', 'O'), ('người', 'O'), ('sở', 'O'), ('hữu', 'O'), ('làn', 'O'), ('da', 'B-SKIN_CONCERNS'), ('nhạy', 'I-SKIN_CONCERNS'), ('cảm', 'I-SKIN_CONCERNS'), ('nhất', 'O')]
# [('Ngoài', 'O'), ('công', 'O'), ('dụng', 'O'), ('làm', 'B-BENEFITS'), ('mờ', 'I-BENEFITS'), ('nám', 'I-BENEFITS'), ('nó', 'O'), ('cũng', 'O'), ('có', 'O'), ('thể:', 'O'), ('Công', 'O'), ('dụng', 'O'), ('của', 'O'), ('Tranexamic', 'B-NAME'), ('Acid', 'I-NAME'), ('trong', 'O'), ('mỹ', 'O'), ('phẩm', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('Tranexamic', 'B-INCI'), ('Axit', 'I-INCI'), ('giúp', 'O'), ('ức', 'O'), ('chế', 'O'), ('hoạt', 'O'), ('động', 'O'), ('của', 'O'), ('enzym', 'O'), ('plasmin', 'O'), ('làm', 'O'), ('chậm', 'O'), ('việc', 'O'), ('sản', 'O'), ('sinh', 'O'), ('nội', 'O'), ('bào', 'O'), ('của', 'O'), ('Arachidonic', 'O'), ('Axit', 'O'), ('cũng', 'O'), ('như', 'O'), ('Hormone', 'O'), ('α-MSH', 'O'), ('yếu', 'O'), ('tố', 'O'), ('kích', 'O'), ('thích', 'O'), ('tổng', 'O'), ('hợp', 'O'), ('Melanin', 'O')]
# [('Chính', 'O'), ('vì', 'O'), ('vậy', 'O'), ('Hexylresorcinol', 'B-NAME'), ('còn', 'O'), ('được', 'O'), ('sử', 'O'), ('dụng', 'O'), ('như', 'O'), ('một', 'O'), ('chất', 'O'), ('bảo', 'O'), ('quản', 'O'), ('dịu', 'O'), ('nhẹ', 'O'), ('và', 'O'), ('an', 'O'), ('toàn', 'O'), ('Công', 'O'), ('thức', 'O'), ('phân', 'O'), ('tử', 'O'), ('của', 'O'), ('Hexylresorcinol', 'B-INCI'), ('Hexylresorcinol', 'B-NAME'), ('là', 'O'), ('thành', 'O'), ('phần', 'O'), ('hiện', 'O'), ('được', 'O'), ('sử', 'O'), ('dụng', 'O'), ('trong', 'O'), ('nhiều', 'O'), ('lĩnh', 'O'), ('vực', 'O'), ('khác', 'O'), ('nhau:', 'O'), ('Về', 'O'), ('mặt', 'O'), ('sinh', 'O'), ('lý', 'O'), ('học', 'O'), ('Hexylresorcinol', 'B-NAME'), ('đã', 'O'), ('được', 'O'), ('nghiên', 'O'), ('cứu', 'O'), ('và', 'O'), ('chứng', 'O'), ('minh', 'O'), ('có', 'O'), ('khả', 'O'), ('năng', 'O'), ('gây', 'O'), ('mê', 'O'), ('sát', 'O'), ('trùng', 'O'), ('nhẹ', 'O')]
# [('Resveratrol', 'B-NAME'), ('là', 'O'), ('hoạt', 'O'), ('chất', 'O'), ('có', 'O'), ('nguồn', 'O'), ('gốc', 'O'), ('thực', 'B-ORIGIN'), ('vật', 'I-ORIGIN'), ('hoạt', 'O'), ('động', 'O'), ('như', 'O'), ('một', 'O'), ('chất', 'O'), ('chống', 'B-BENEFITS'), ('oxy', 'I-BENEFITS'), ('hóa', 'I-BENEFITS')]
# [('Vì', 'O'), ('thế', 'O'), ('việc', 'O'), ('bổ', 'O'), ('sung', 'O'), ('Peptide', 'B-NAME'), ('sẽ', 'O'), ('tác', 'O'), ('động', 'O'), ('sâu', 'O'), ('sắc', 'O'), ('đến', 'O'), ('nhiều', 'O'), ('phương', 'O'), ('diện', 'O'), ('của', 'O'), ('hoạt', 'O'), ('động', 'O'), ('tế', 'O'), ('bào', 'O'), ('trong', 'O'), ('đó', 'O'), ('không', 'O'), ('thể', 'O'), ('bỏ', 'O'), ('qua', 'O'), ('hoạt', 'O'), ('động', 'O'), ('tái', 'B-BENEFITS'), ('tạo', 'I-BENEFITS'), ('Collagen', 'I-BENEFITS'), ('giúp', 'B-BENEFITS'), ('da', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('và', 'O'), ('ngăn', 'B-BENEFITS'), ('ngừa', 'I-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS')]
# [('Khi', 'O'), ('da', 'B-SKIN_CONCERNS'), ('có', 'I-SKIN_CONCERNS'), ('những', 'I-SKIN_CONCERNS'), ('nốt', 'I-SKIN_CONCERNS'), ('sưng', 'I-SKIN_CONCERNS'), ('nhẹ', 'I-SKIN_CONCERNS'), ('Tea', 'B-NAME'), ('Tree', 'I-NAME'), ('Oil', 'I-NAME'), ('thường', 'O'), ('giúp', 'O'), ('làm', 'O'), ('dịu', 'O'), ('rõ', 'O'), ('rệt', 'O')]
# [('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('(HA)', 'O'), ('là', 'O'), ('một', 'O'), ('phân', 'O'), ('tử', 'O'), ('đường', 'O'), ('tên', 'O'), ('khoa', 'O'), ('học', 'O'), ('là', 'O'), ('Polysaccharide', 'B-INCI'), ('có', 'O'), ('khối', 'O'), ('lượng', 'O'), ('phân', 'O'), ('tử', 'O'), ('nằm', 'O'), ('trong', 'O'), ('khoảng', 'O'), ('600', 'O'), ('000', 'O'), ('đến', 'O'), ('1', 'O'), ('000', 'O'), ('000', 'O'), ('đơn', 'O'), ('vị', 'O'), ('Dalton', 'O'), ('lớn', 'O'), ('hơn', 'O'), ('30', 'O'), ('000', 'O'), ('phân', 'O'), ('tử', 'O'), ('đường', 'O'), ('thông', 'O'), ('thường', 'O'), ('(340', 'O'), ('Dalton)', 'O')]
# [('Licorice', 'B-NAME'), ('Extract', 'I-NAME'), ('được', 'O'), ('yêu', 'O'), ('thích', 'O'), ('vì', 'O'), ('giúp', 'B-BENEFITS'), ('làm', 'I-BENEFITS'), ('sáng', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('tự', 'I-BENEFITS'), ('nhiên', 'I-BENEFITS'), ('nhờ', 'O'), ('glabridin', 'O'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('giảm', 'I-BENEFITS'), ('tình', 'I-BENEFITS'), ('trạng', 'I-BENEFITS'), ('tối', 'I-BENEFITS'), ('màu', 'I-BENEFITS')]
# [('Giảm', 'O'), ('nguy', 'O'), ('cơ', 'O'), ('viêm', 'O'), ('da', 'O'), ('da', 'O'), ('mẩn', 'O'), ('đỏ:', 'O'), ('Resveratrol', 'B-NAME'), ('được', 'O'), ('chứng', 'O'), ('minh', 'O'), ('là', 'O'), ('có', 'O'), ('tác', 'O'), ('dụng', 'O'), ('làm', 'B-BENEFITS'), ('dịu', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('từ', 'O'), ('đó', 'O'), ('giúp', 'O'), ('giảm', 'O'), ('nguy', 'O'), ('cơ', 'O'), ('viêm', 'B-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('da', 'B-SKIN_CONCERNS'), ('mẩn', 'I-SKIN_CONCERNS'), ('đỏ', 'I-SKIN_CONCERNS')]
# [('Nhờ', 'O'), ('khả', 'O'), ('năng', 'O'), ('kích', 'O'), ('thích', 'O'), ('sản', 'O'), ('sinh', 'O'), ('collagen', 'B-NAME'), ('và', 'O'), ('elastin', 'B-NAME'), ('Niacinamide', 'B-NAME'), ('còn', 'O'), ('giúp', 'B-BENEFITS'), ('giảm', 'I-BENEFITS'), ('nếp', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS'), ('tăng', 'B-BENEFITS'), ('độ', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('và', 'O'), ('cải', 'B-BENEFITS'), ('thiện', 'I-BENEFITS'), ('kết', 'I-BENEFITS'), ('cấu', 'I-BENEFITS'), ('da', 'I-BENEFITS')]
# ...
# [('Kojic', 'B-NAME'), ('acid', 'I-NAME'), ('hỗ', 'O'), ('trợ', 'O'), ('điều', 'B-BENEFITS'), ('trị', 'I-BENEFITS'), ('nám', 'I-BENEFITS')]
# [('Allantoin', 'B-INCI'), ('được', 'O'), ('tìm', 'O'), ('thấy', 'O'), ('trong', 'O'), ('cây', 'B-ORIGIN'), ('Comfrey', 'I-ORIGIN'), ('thuộc', 'O'), ('vùng', 'O'), ('của', 'O'), ('Châu', 'O'), ('Á', 'O'), ('Bắc', 'O'), ('Mỹ', 'O'), ('và', 'O'), ('Châu', 'O'), ('Âu', 'O')]
# [('Các', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('dưỡng', 'O'), ('đêm', 'O'), ('hay', 'O'), ('dùng', 'O'), ('Adenosine', 'B-NAME'), ('để', 'O'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('tái', 'I-BENEFITS'), ('tạo', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('sau', 'O'), ('ngày', 'O'), ('dài', 'O'), ('tiếp', 'O'), ('xúc', 'O'), ('nắng', 'O'), ('nóng', 'O')]
# [('Tác', 'O'), ('dụng', 'O'), ('của', 'O'), ('Retinol', 'B-NAME'), ('là', 'O'), ('sẽ', 'O'), ('tác', 'O'), ('động', 'O'), ('đến', 'O'), ('các', 'O'), ('tế', 'O'), ('bào', 'O'), ('khác', 'O'), ('của', 'O'), ('làn', 'O'), ('da', 'O'), ('thẩm', 'O'), ('thấu', 'O'), ('vào', 'O'), ('da', 'O'), ('và', 'O'), ('tăng', 'B-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('tái', 'I-BENEFITS'), ('sinh', 'I-BENEFITS'), ('tế', 'I-BENEFITS'), ('bào', 'I-BENEFITS'), ('kích', 'B-BENEFITS'), ('thích', 'I-BENEFITS'), ('sản', 'I-BENEFITS'), ('sinh', 'I-BENEFITS'), ('Collagen', 'I-BENEFITS'), ('cũng', 'O'), ('như', 'O'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('trị', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('và', 'O'), ('kháng', 'B-BENEFITS'), ('khuẩn', 'I-BENEFITS'), ('từ', 'O'), ('đó', 'O'), ('giúp', 'B-BENEFITS'), ('trẻ', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('làn', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('cải', 'O'), ('thiện', 'O'), ('hầu', 'O'), ('hết', 'O'), ('các', 'O'), ('vấn', 'O'), ('đề', 'O'), ('da', 'O'), ('đang', 'O'), ('gặp', 'O'), ('phải', 'O'), ('mang', 'O'), ('đến', 'O'), ('cho', 'O'), ('bạn', 'O'), ('làn', 'O'), ('da', 'O'), ('rạng', 'O'), ('rỡ', 'O'), ('không', 'O'), ('tì', 'O'), ('vết', 'O')]
# [('Da', 'B-SKIN_CONCERNS'), ('dễ', 'I-SKIN_CONCERNS'), ('bong', 'I-SKIN_CONCERNS'), ('tróc', 'I-SKIN_CONCERNS'), ('nhẹ', 'O'), ('do', 'O'), ('khô', 'O'), ('thường', 'O'), ('được', 'O'), ('gợi', 'O'), ('ý', 'O'), ('bổ', 'O'), ('sung', 'O'), ('PGA', 'B-NAME'), ('để', 'O'), ('ổn', 'O'), ('định', 'O'), ('lại', 'O'), ('độ', 'O'), ('ẩm', 'O')]
# [('Chữa', 'O'), ('lành:', 'O'), ('Thông', 'O'), ('qua', 'O'), ('việc', 'O'), ('làm', 'B-BENEFITS'), ('dịu', 'I-BENEFITS'), ('chống', 'B-BENEFITS'), ('viêm', 'I-BENEFITS'), ('và', 'O'), ('kháng', 'B-BENEFITS'), ('khuẩn', 'I-BENEFITS'), ('bisabolol', 'O'), ('góp', 'O'), ('phần', 'O'), ('vào', 'O'), ('quá', 'O'), ('trình', 'O'), ('chữa', 'O'), ('lành', 'O'), ('các', 'O'), ('tổn', 'B-SKIN_CONCERNS'), ('thương', 'I-SKIN_CONCERNS'), ('trên', 'O'), ('da', 'O'), ('giúp', 'O'), ('làm', 'O'), ('giảm', 'B-BENEFITS'), ('thâm', 'I-BENEFITS'), ('sẹo', 'I-BENEFITS'), ('và', 'O'), ('các', 'O'), ('triệu', 'O'), ('chứng', 'O'), ('kích', 'B-SKIN_CONCERNS'), ('ứng', 'I-SKIN_CONCERNS')]
# [('Hexylresorcinol', 'B-NAME'), ('(HR)', 'O'), ('là', 'O'), ('một', 'O'), ('lipid', 'O'), ('Phenol', 'B-NAME'), ('hay', 'O'), ('còn', 'O'), ('gọi', 'O'), ('là', 'O'), ('Alkyl', 'B-NAME'), ('Resorcinol', 'I-NAME'), ('(AR)', 'O'), ('có', 'O'), ('chuỗi', 'O'), ('n-hexyl', 'O'), ('được', 'O'), ('gắn', 'O'), ('vào', 'O'), ('vị', 'O'), ('trí', 'O'), ('thứ', 'O'), ('4', 'O'), ('của', 'O'), ('vòng', 'O'), ('1', 'B-NAME'), ('3-dihydroxybenzene', 'I-NAME')]
# [('Licorice', 'B-NAME'), ('Extract', 'I-NAME'), ('có', 'O'), ('nguồn', 'O'), ('gốc', 'O'), ('từ', 'B-ORIGIN'), ('rễ', 'I-ORIGIN'), ('cây', 'I-ORIGIN'), ('cam', 'I-ORIGIN'), ('thảo', 'I-ORIGIN'), ('Glycyrrhiza', 'I-ORIGIN'), ('Glabra', 'I-ORIGIN'), ('–', 'O'), ('loại', 'O'), ('cây', 'O'), ('được', 'O'), ('dùng', 'O'), ('lâu', 'O'), ('đời', 'O'), ('trong', 'O'), ('y', 'O'), ('học', 'O'), ('phương', 'O'), ('Đông', 'O')]
# [('Nhờ', 'O'), ('có', 'O'), ('đặc', 'O'), ('tính', 'O'), ('kháng', 'B-BENEFITS'), ('khuẩn', 'I-BENEFITS'), ('sulfur', 'B-NAME'), ('từ', 'O'), ('lâu', 'O'), ('đã', 'O'), ('được', 'O'), ('sử', 'O'), ('dụng', 'O'), ('trong', 'O'), ('nhiều', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('điều', 'O'), ('trị', 'O'), ('mụn', 'O'), ('trứng', 'O'), ('cá', 'O'), ('và', 'O'), ('các', 'O'), ('tình', 'O'), ('trạng', 'O'), ('da', 'O'), ('khác', 'O')]
# [('Đây', 'O'), ('là', 'O'), ('lý', 'O'), ('do', 'O'), ('tại', 'O'), ('sao', 'O'), ('dầu', 'O'), ('Squalane', 'B-NAME'), ('vừa', 'O'), ('có', 'O'), ('tác', 'O'), ('dụng', 'O'), ('bảo', 'B-BENEFITS'), ('vệ', 'I-BENEFITS'), ('vừa', 'O'), ('là', 'O'), ('một', 'O'), ('thành', 'O'), ('phần', 'O'), ('dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('nhẹ', 'O'), ('tuyệt', 'O'), ('vời', 'O')]
# [('Nhiều', 'O'), ('thương', 'O'), ('hiệu', 'O'), ('hiện', 'O'), ('đang', 'O'), ('sử', 'O'), ('dụng', 'O'), ('các', 'O'), ('chất', 'O'), ('thay', 'O'), ('thế', 'O'), ('cholesterol', 'B-NAME'), ('tổng', 'O'), ('hợp', 'O'), ('hoặc', 'O'), ('có', 'O'), ('nguồn', 'O'), ('gốc', 'O'), ('thực', 'B-ORIGIN'), ('vật', 'I-ORIGIN'), ('để', 'O'), ('đáp', 'O'), ('ứng', 'O'), ('nhu', 'O'), ('cầu', 'O'), ('cho', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('thuần', 'O'), ('chay', 'O'), ('và', 'O'), ('“sạch”', 'O')]
# [('Cải', 'O'), ('thiện', 'O'), ('kết', 'O'), ('cấu', 'O'), ('da', 'O'), (':', 'O'), ('Sử', 'O'), ('dụng', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('chứa', 'O'), ('axit', 'B-INCI'), ('salicylic', 'I-INCI'), ('thường', 'O'), ('xuyên', 'O'), ('giúp', 'O'), ('da', 'B-BENEFITS'), ('trở', 'I-BENEFITS'), ('nên', 'I-BENEFITS'), ('mịn', 'I-BENEFITS'), ('màng', 'I-BENEFITS'), ('đều', 'I-BENEFITS'), ('màu', 'I-BENEFITS'), ('hơn', 'O'), ('đồng', 'O'), ('thời', 'O'), ('làm', 'O'), ('mờ', 'B-BENEFITS'), ('các', 'I-BENEFITS'), ('vết', 'I-BENEFITS'), ('thâm', 'I-BENEFITS'), ('sẹo', 'I-BENEFITS'), ('do', 'I-BENEFITS'), ('mụn', 'I-BENEFITS'), ('để', 'I-BENEFITS'), ('lại', 'I-BENEFITS')]
# [('Do', 'O'), ('đó', 'O'), ('việc', 'O'), ('bổ', 'O'), ('sung', 'O'), ('Cholesterol', 'B-NAME'), ('từ', 'O'), ('các', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('có', 'O'), ('thể', 'O'), ('giúp', 'O'), ('củng', 'B-BENEFITS'), ('cố', 'I-BENEFITS'), ('hàng', 'I-BENEFITS'), ('rào', 'I-BENEFITS'), ('bảo', 'I-BENEFITS'), ('vệ', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('từ', 'O'), ('đó', 'O'), ('hạn', 'B-BENEFITS'), ('chế', 'I-BENEFITS'), ('mất', 'I-BENEFITS'), ('nước', 'I-BENEFITS'), ('và', 'O'), ('giảm', 'B-BENEFITS'), ('thiểu', 'I-BENEFITS'), ('được', 'I-BENEFITS'), ('tình', 'I-BENEFITS'), ('trạng', 'I-BENEFITS'), ('khô', 'I-BENEFITS'), ('ngứa', 'I-BENEFITS'), ('kích', 'I-BENEFITS'), ('ứng', 'I-BENEFITS'), ('do', 'O'), ('ảnh', 'O'), ('hưởng', 'O'), ('từ', 'O'), ('các', 'O'), ('tác', 'O'), ('nhân', 'O'), ('môi', 'O'), ('trường', 'O')]
# [('Một', 'O'), ('trong', 'O'), ('những', 'O'), ('lợi', 'O'), ('ích', 'O'), ('lớn', 'O'), ('của', 'O'), ('PGA', 'B-NAME'), ('là', 'O'), ('khả', 'O'), ('năng', 'O'), ('khóa', 'O'), ('ẩm', 'O'), ('hiệu', 'O'), ('quả', 'O'), ('giúp', 'B-BENEFITS'), ('da', 'I-BENEFITS'), ('hạn', 'I-BENEFITS'), ('chế', 'I-BENEFITS'), ('thất', 'I-BENEFITS'), ('thoát', 'I-BENEFITS'), ('nước', 'I-BENEFITS'), ('xuyên', 'O'), ('biểu', 'O'), ('bì', 'O')]
# [('Tuy', 'O'), ('nhiên', 'O'), ('trải', 'O'), ('nghiệm', 'O'), ('với', 'O'), ('Bakuchiol', 'B-NAME'), ('sẽ', 'O'), ('hoàn', 'O'), ('toàn', 'O'), ('là', 'O'), ('sự', 'O'), ('khác', 'O'), ('biệt', 'O')]
# [('Vào', 'O'), ('thời', 'O'), ('điểm', 'O'), ('đó', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('sẽ', 'O'), ('giúp', 'B-BENEFITS'), ('làm', 'I-BENEFITS'), ('dịu', 'I-BENEFITS'), ('và', 'O'), ('giảm', 'B-BENEFITS'), ('sưng', 'I-BENEFITS'), ('tấy', 'I-BENEFITS'), ('cho', 'O'), ('làn', 'B-SKIN_CONCERNS'), ('da', 'I-SKIN_CONCERNS'), ('kích', 'I-SKIN_CONCERNS'), ('ứng', 'I-SKIN_CONCERNS'), ('hiệu', 'O'), ('quả', 'O'), ('Được', 'O'), ('chứng', 'O'), ('minh', 'O'), ('bởi', 'O'), ('độ', 'O'), ('an', 'O'), ('toàn', 'O'), ('dịu', 'O'), ('nhẹ', 'O'), ('và', 'O'), ('lành', 'O'), ('tính', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('phù', 'O'), ('hợp', 'O'), ('với', 'O'), ('mọi', 'O'), ('loại', 'O'), ('da', 'O'), ('đặc', 'O'), ('biệt', 'O'), ('là', 'O'), ('da', 'B-SKIN_CONCERNS'), ('nhạy', 'I-SKIN_CONCERNS'), ('cảm', 'I-SKIN_CONCERNS'), ('Đặc', 'O'), ('tính', 'O'), ('liên', 'O'), ('kết', 'O'), ('độ', 'O'), ('ẩm', 'O'), ('của', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('đặc', 'O'), ('biệt', 'O'), ('quan', 'O'), ('trọng', 'O'), ('đối', 'O'), ('với', 'O'), ('quá', 'O'), ('trình', 'O'), ('lão', 'O'), ('hóa', 'O'), ('da', 'O')]
# [('Do', 'O'), ('đó', 'O'), ('Beta', 'B-NAME'), ('Glucan', 'I-NAME'), ('được', 'O'), ('dùng', 'O'), ('nhiều', 'O'), ('trong', 'O'), ('mỹ', 'O'), ('phẩm', 'O'), ('với', 'O'), ('mục', 'O'), ('đích', 'O'), ('dưỡng', 'B-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('hoàn', 'O'), ('hảo', 'O')]
# [('Là', 'O'), ('glycosaminoglycan', 'B-NAME'), ('chính', 'O'), ('trong', 'O'), ('da', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('hoạt', 'O'), ('động', 'O'), ('để', 'O'), ('giữ', 'B-BENEFITS'), ('cho', 'I-BENEFITS'), ('cấu', 'I-BENEFITS'), ('trúc', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('ổn', 'I-BENEFITS'), ('định', 'I-BENEFITS'), ('duy', 'B-BENEFITS'), ('trì', 'I-BENEFITS'), ('sự', 'I-BENEFITS'), ('đàn', 'I-BENEFITS'), ('hồi', 'I-BENEFITS'), ('và', 'O'), ('căng', 'B-BENEFITS'), ('mọng', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('da', 'I-BENEFITS')]
# [('Đây', 'O'), ('là', 'O'), ('lý', 'O'), ('do', 'O'), ('vì', 'O'), ('sao', 'O'), ('bạn', 'O'), ('sẽ', 'O'), ('tìm', 'O'), ('thấy', 'O'), ('bisabolol', 'B-NAME'), ('trong', 'O'), ('một', 'O'), ('số', 'O'), ('sản', 'O'), ('phẩm', 'O'), ('điều', 'O'), ('trị', 'O'), ('mụn', 'B-SKIN_CONCERNS')]
# [('Tea', 'B-NAME'), ('Tree', 'I-NAME'), ('Oil', 'I-NAME'), ('thường', 'O'), ('được', 'O'), ('thêm', 'O'), ('vào', 'O'), ('routine', 'O'), ('vì', 'O'), ('hỗ', 'B-BENEFITS'), ('trợ', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('thông', 'I-BENEFITS'), ('thoáng', 'I-BENEFITS'), ('hơn', 'I-BENEFITS'), ('sau', 'O'), ('một', 'O'), ('thời', 'O'), ('gian', 'O'), ('dùng', 'O')]
# [('Copper', 'O'), ('Peptide', 'B-NAME'), ('hoạt', 'O'), ('động', 'O'), ('với', 'O'), ('cơ', 'O'), ('chế', 'O'), ('thúc', 'B-BENEFITS'), ('đẩy', 'I-BENEFITS'), ('sản', 'I-BENEFITS'), ('sinh', 'I-BENEFITS'), ('Collagen', 'I-BENEFITS'), ('Elastin', 'O'), ('và', 'O'), ('Glycosaminoglycan', 'O'), ('tái', 'B-BENEFITS'), ('sinh', 'I-BENEFITS'), ('các', 'I-BENEFITS'), ('lớp', 'I-BENEFITS'), ('biểu', 'I-BENEFITS'), ('bì', 'I-BENEFITS'), ('phục', 'B-BENEFITS'), ('hồi', 'I-BENEFITS'), ('làn', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('hiệu', 'I-BENEFITS'), ('quả', 'I-BENEFITS'), ('và', 'O'), ('chống', 'B-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('tối', 'O'), ('ưu', 'O')]
# [('Beta', 'B-NAME'), ('glucan', 'I-NAME'), ('có', 'O'), ('chức', 'O'), ('năng', 'O'), ('bảo', 'B-BENEFITS'), ('vệ', 'I-BENEFITS'), ('làn', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('khỏi', 'O'), ('sự', 'O'), ('tấn', 'O'), ('công', 'O'), ('của', 'O'), ('các', 'O'), ('vi', 'O'), ('khuẩn', 'O'), ('có', 'O'), ('hại', 'O')]
# [('Từ', 'O'), ('đó', 'O'), ('ngăn', 'B-BENEFITS'), ('ngừa', 'I-BENEFITS'), ('quá', 'I-BENEFITS'), ('trình', 'I-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('giảm', 'B-BENEFITS'), ('tốc', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('hình', 'I-BENEFITS'), ('thành', 'I-BENEFITS'), ('nếp', 'I-BENEFITS'), ('nhăn', 'I-BENEFITS')]
# [('Nghiên', 'O'), ('cứu', 'O'), ('cho', 'O'), ('thấy', 'O'), ('avena', 'B-INCI'), ('sativa', 'I-INCI'), ('giúp', 'O'), ('cải', 'B-BENEFITS'), ('thiện', 'I-BENEFITS'), ('đáng', 'I-BENEFITS'), ('kể', 'I-BENEFITS'), ('tình', 'I-BENEFITS'), ('trạng', 'I-BENEFITS'), ('đóng', 'I-BENEFITS'), ('vảy', 'I-BENEFITS'), ('khô', 'O'), ('da', 'O'), ('và', 'O'), ('duy', 'B-BENEFITS'), ('trì', 'I-BENEFITS'), ('độ', 'I-BENEFITS'), ('ẩm', 'I-BENEFITS'), ('sau', 'I-BENEFITS'), ('khi', 'O'), ('ngưng', 'O'), ('sử', 'O'), ('dụng', 'O')]
# [('Retinol', 'B-NAME'), ('hoạt', 'O'), ('động', 'O'), ('giống', 'O'), ('như', 'O'), ('một', 'O'), ('thành', 'O'), ('phần', 'O'), ('liên', 'O'), ('kết', 'O'), ('tế', 'O'), ('bào', 'O'), ('trung', 'O'), ('hòa', 'O'), ('các', 'O'), ('gốc', 'O'), ('tự', 'O'), ('do', 'O'), ('phía', 'O'), ('trong', 'O'), ('da', 'O')]
# [('Sự', 'O'), ('có', 'O'), ('mặt', 'O'), ('và', 'O'), ('tham', 'O'), ('gia', 'O'), ('của', 'O'), ('Niacinamide', 'B-NAME'), ('trong', 'O'), ('quy', 'O'), ('trình', 'O'), ('chăm', 'O'), ('sóc', 'O'), ('da', 'O'), ('sẽ', 'O'), ('giúp', 'O'), ('tái', 'O'), ('tạo', 'O'), ('và', 'O'), ('củng', 'O'), ('cố', 'O'), ('“hàng', 'O'), ('rào”', 'O'), ('này', 'O'), ('trở', 'O'), ('nên', 'O'), ('kiên', 'O'), ('cố', 'O'), ('tăng', 'O'), ('sản', 'O'), ('sinh', 'O'), ('các', 'O'), ('lấy', 'B-BENEFITS'), ('lại', 'I-BENEFITS'), ('sự', 'I-BENEFITS'), ('trẻ', 'I-BENEFITS'), ('trung', 'I-BENEFITS'), ('mềm', 'I-BENEFITS'), ('mịn', 'I-BENEFITS'), ('vốn', 'O'), ('có', 'O')]
# [('Da', 'O'), ('trở', 'O'), ('nên', 'O'), ('khô', 'O'), ('và', 'O'), ('thiếu', 'O'), ('sức', 'O'), ('sống', 'O'), ('khi', 'O'), ('thiếu', 'O'), ('hụt', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('Các', 'O'), ('phân', 'O'), ('tử', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('hoạt', 'O'), ('động', 'O'), ('như', 'O'), ('một', 'O'), ('miếng', 'O'), ('mút', 'O'), ('hút', 'O'), ('ẩm', 'O'), ('từ', 'O'), ('môi', 'O'), ('trường', 'O'), ('bên', 'O'), ('ngoài', 'O'), ('và', 'O'), ('từ', 'O'), ('các', 'O'), ('tầng', 'O'), ('da', 'O'), ('bên', 'O'), ('dưới', 'O'), ('lên', 'O'), ('trên', 'O'), ('bề', 'O'), ('mặt', 'O'), ('da', 'O'), ('giúp', 'B-BENEFITS'), ('bề', 'I-BENEFITS'), ('mặt', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('trở', 'I-BENEFITS'), ('nên', 'I-BENEFITS'), ('căng', 'I-BENEFITS'), ('mọng', 'I-BENEFITS'), ('ngậm', 'O'), ('nước', 'O')]
# [('Những', 'O'), ('bạn', 'O'), ('gặp', 'O'), ('tình', 'O'), ('trạng', 'O'), ('da', 'B-SKIN_CONCERNS'), ('sạm', 'I-SKIN_CONCERNS'), ('nhẹ', 'I-SKIN_CONCERNS'), ('do', 'I-SKIN_CONCERNS'), ('nắng', 'I-SKIN_CONCERNS'), ('thường', 'O'), ('dùng', 'O'), ('serum', 'O'), ('có', 'O'), ('EGCG', 'B-NAME'), ('để', 'O'), ('cải', 'O'), ('thiện', 'O'), ('tone', 'O'), ('da', 'O')]
# [('Một', 'O'), ('trong', 'O'), ('số', 'O'), ('những', 'O'), ('tác', 'O'), ('dụng', 'O'), ('mà', 'O'), ('Coenzyme', 'B-NAME'), ('Q10', 'I-NAME'), ('đem', 'O'), ('lại', 'O'), ('cho', 'O'), ('làn', 'O'), ('da', 'O'), ('đó', 'O'), ('là', 'O'), ('luôn', 'O'), ('giúp', 'O'), ('cho', 'O'), ('da', 'O'), ('được', 'O'), ('trắng', 'O'), ('sáng', 'O'), ('ngay', 'O'), ('cả', 'O'), ('khi', 'O'), ('bạn', 'O'), ('sở', 'O'), ('hữu', 'O'), ('làn', 'O'), ('da', 'B-SKIN_CONCERNS'), ('không', 'I-SKIN_CONCERNS'), ('đều', 'I-SKIN_CONCERNS'), ('màu', 'I-SKIN_CONCERNS'), ('hoặc', 'O'), ('da', 'B-SKIN_CONCERNS'), ('ngăm', 'I-SKIN_CONCERNS')]
# [('Sau', 'O'), ('tất', 'O'), ('cả', 'O'), ('những', 'O'), ('công', 'O'), ('dụng', 'O'), ('trên', 'O'), ('Hyaluronic', 'B-NAME'), ('Acid', 'I-NAME'), ('chính', 'O'), ('là', 'O'), ('áo', 'O'), ('giáp', 'O'), ('chống', 'B-BENEFITS'), ('lão', 'I-BENEFITS'), ('hóa', 'I-BENEFITS'), ('chống', 'B-BENEFITS'), ('lại', 'I-BENEFITS'), ('những', 'I-BENEFITS'), ('vấn', 'I-BENEFITS'), ('đề', 'I-BENEFITS'), ('gây', 'I-BENEFITS'), ('tổn', 'I-BENEFITS'), ('thương', 'I-BENEFITS'), ('từ', 'I-BENEFITS'), ('gốc', 'I-BENEFITS'), ('rễ', 'I-BENEFITS'), ('của', 'I-BENEFITS'), ('da', 'I-BENEFITS'), ('và', 'O'), ('làm', 'B-BENEFITS'), ('giảm', 'I-BENEFITS'), ('sưng', 'I-BENEFITS'), ('tấy', 'I-BENEFITS')]
